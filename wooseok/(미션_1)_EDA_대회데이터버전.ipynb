# %% [markdown]
# # (0) RecSys 기초 대회 미션1
#
# Book recommondation Dataset EDA
#
# 탐색적 데이터 분석이라고 불리는 EDA (Exploratory Data Analysis)는 수집한 데이터를 다양한 각도에서 관찰하고 이해하는 과정을 말합니다.
#
# 기본적으로 데이터를 잘 파악해야 새로운 인사이트를 발견하고, 이를 분석에 활용하여 더 높은 성능을 내기 위한 다양한 실험을 해볼 수 있습니다.
#
# 본 미션을 통해 추후 모델의 성능 향상에 도움이 될만한 새로운 아이디어를 떠올릴 수 있는 시간을 갖게 될 것입니다.

# %% [markdown]
# # (1) 데이터
#
# RecSys 기초 대회 강의에서는Book Crossing 데이터를 사용하여, 모든 실습 및 미션, 대회를 진행합니다. [Kaggle Book-Crossing](https://www.kaggle.com/datasets/ruchi798/bookcrossing-dataset) 을 출처로 하며, 데이터는 재구성되어 제공되었습니다. 해당 데이터는 CC0: Public Domain 라이센스임을 밝힙니다.
#
#
#
# 본 대회에 활용되는 데이터는 총 3개의 파일입니다.
#
# user : 사용자 정보를 담고 있는 데이터 파일
#
# ratings: 책의 등급을 1-10으로 표현한 데이터 파일
#
# books: 책과 관련된 정보를 표현한 데이터 파일
#
# 먼저 세 파일을 로드하는 과정을 수행하겠습니다.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=17Zbpx_Yn0ggLFVeijUalcnOUt5mCHeEH' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=17Zbpx_Yn0ggLFVeijUalcnOUt5mCHeEH" -O users.csv && rm -rf ~/cookies.txt
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1JIxWPgC8JJkuZaWjk5FJBBKuqSX87HGE' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1JIxWPgC8JJkuZaWjk5FJBBKuqSX87HGE" -O books.csv && rm -rf ~/cookies.txt
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1B-8lw3a1KPJdhFAMXP58a7taJjpDvfw6' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1B-8lw3a1KPJdhFAMXP58a7taJjpDvfw6" -O ratings.csv && rm -rf ~/cookies.txt

# %%
# !wget https://aistages-prod-server-public.s3.amazonaws.com/app/Competitions/000210/data/data.tar.gz
# Out:
# --2022-10-25 15:13:54--  https://aistages-prod-server-public.s3.amazonaws.com/app/Competitions/000210/data/data.tar.gz
# Resolving aistages-prod-server-public.s3.amazonaws.com (aistages-prod-server-public.s3.amazonaws.com)... 52.92.147.9
# Connecting to aistages-prod-server-public.s3.amazonaws.com (aistages-prod-server-public.s3.amazonaws.com)|52.92.147.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 235487688 (225M) [application/x-gzip]
# Saving to: ‘data.tar.gz’
#
# data.tar.gz         100%[===================>] 224.58M  17.8MB/s    in 14s
#
# 2022-10-25 15:14:08 (16.2 MB/s) - ‘data.tar.gz’ saved [235487688/235487688]

# %%
# !unzip data.tar.gz
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: images/4770028601.01.THUMBZZZ.jpg
#   inflating: images/4770028962.01.THUMBZZZ.jpg
#   inflating: images/4770029055.01.THUMBZZZ.jpg
#   inflating: images/4770029489.01.THUMBZZZ.jpg
#   inflating: images/4789000583.01.THUMBZZZ.jpg
#   inflating: images/4789000680.01.THUMBZZZ.jpg
#   inflating: images/4789005178.01.THUMBZZZ.jpg
#   inflating: images/4817090014.01.THUMBZZZ.jpg
#   inflating: images/4834009424.01.THUMBZZZ.jpg
#   inflating: images/4887755171.01.THUMBZZZ.jpg
#   inflating: images/4888720029.01.THUMBZZZ.jpg
#   inflating: images/4888720134.01.THUMBZZZ.jpg
#   inflating: images/4888720266.01.THUMBZZZ.jpg
#   inflating: images/4888720304.01.THUMBZZZ.jpg
#   inflating: images/4889960457.01.THUMBZZZ.jpg
#   inflating: images/4889960465.01.THUMBZZZ.jpg
#   inflating: images/4889960724.01.THUMBZZZ.jpg
#   inflating: images/4889960767.01.THUMBZZZ.jpg
#   inflating: images/4889960929.01.THUMBZZZ.jpg
#   inflating: images/4889961151.01.THUMBZZZ.jpg
#   inflating: images/4890110917.01.THUMBZZZ.jpg
#   inflating: images/4906574467.01.THUMBZZZ.jpg
#   inflating: images/5020054542.01.THUMBZZZ.jpg
#   inflating: images/5030008004.01.THUMBZZZ.jpg
#   inflating: images/5050011280.01.THUMBZZZ.jpg
#   inflating: images/5353004329.01.THUMBZZZ.jpg
#   inflating: images/5415008233.01.THUMBZZZ.jpg
#   inflating: images/542001226X.01.THUMBZZZ.jpg
#   inflating: images/5550205599.01.THUMBZZZ.jpg
#   inflating: images/555053150X.01.THUMBZZZ.jpg
#   inflating: images/5550534274.01.THUMBZZZ.jpg
#   inflating: images/555097598X.01.THUMBZZZ.jpg
#   inflating: images/555111614X.01.THUMBZZZ.jpg
#   inflating: images/5551172945.01.THUMBZZZ.jpg
#   inflating: images/5551500187.01.THUMBZZZ.jpg
#   inflating: images/5551696006.01.THUMBZZZ.jpg
#   inflating: images/5551732509.01.THUMBZZZ.jpg
#   inflating: images/5551776328.01.THUMBZZZ.jpg
#   inflating: images/5551973522.01.THUMBZZZ.jpg
#   inflating: images/5552022920.01.THUMBZZZ.jpg
#   inflating: images/5552165306.01.THUMBZZZ.jpg
#   inflating: images/5552446135.01.THUMBZZZ.jpg
#   inflating: images/5552552660.01.THUMBZZZ.jpg
#   inflating: images/5553465214.01.THUMBZZZ.jpg
#   inflating: images/5553531144.01.THUMBZZZ.jpg
#   inflating: images/5553676770.01.THUMBZZZ.jpg
#   inflating: images/5553861977.01.THUMBZZZ.jpg
#   inflating: images/5556053901.01.THUMBZZZ.jpg
#   inflating: images/5557121005.01.THUMBZZZ.jpg
#   inflating: images/5845105129.01.THUMBZZZ.jpg
#   inflating: images/7108009153.01.THUMBZZZ.jpg
#   inflating: images/710800982X.01.THUMBZZZ.jpg
#   inflating: images/7119000306.01.THUMBZZZ.jpg
#   inflating: images/7561910908.01.THUMBZZZ.jpg
#   inflating: images/7800051846.01.THUMBZZZ.jpg
#   inflating: images/7806680632.01.THUMBZZZ.jpg
#   inflating: images/8020206469.01.THUMBZZZ.jpg
#   inflating: images/8023833847.01.THUMBZZZ.jpg
#   inflating: images/802385173X.01.THUMBZZZ.jpg
#   inflating: images/8071812447.01.THUMBZZZ.jpg
#   inflating: images/8085128829.01.THUMBZZZ.jpg
#   inflating: images/8090128920.01.THUMBZZZ.jpg
#   inflating: images/8120724399.01.THUMBZZZ.jpg
#   inflating: images/8120813871.01.THUMBZZZ.jpg
#   inflating: images/8170187184.01.THUMBZZZ.jpg
#   inflating: images/8170215404.01.THUMBZZZ.jpg
#   inflating: images/8170217210.01.THUMBZZZ.jpg
#   inflating: images/8171670407.01.THUMBZZZ.jpg
#   inflating: images/8171677347.01.THUMBZZZ.jpg
#   inflating: images/8172234104.01.THUMBZZZ.jpg
#   inflating: images/8172610041.01.THUMBZZZ.jpg
#   inflating: images/8172610750.01.THUMBZZZ.jpg
#   inflating: images/8173711461.01.THUMBZZZ.jpg
#   inflating: images/817436076X.01.THUMBZZZ.jpg
#   inflating: images/8175252723.01.THUMBZZZ.jpg
#   inflating: images/8176210919.01.THUMBZZZ.jpg
#   inflating: images/8185063133.01.THUMBZZZ.jpg
#   inflating: images/8185326207.01.THUMBZZZ.jpg
#   inflating: images/818567440X.01.THUMBZZZ.jpg
#   inflating: images/8185985189.01.THUMBZZZ.jpg
#   inflating: images/8186953019.01.THUMBZZZ.jpg
#   inflating: images/8188086010.01.THUMBZZZ.jpg
#   inflating: images/8200063887.01.THUMBZZZ.jpg
#   inflating: images/8202159040.01.THUMBZZZ.jpg
#   inflating: images/8202201438.01.THUMBZZZ.jpg
#   inflating: images/8203178960.01.THUMBZZZ.jpg
#   inflating: images/8205232318.01.THUMBZZZ.jpg
#   inflating: images/8249500032.01.THUMBZZZ.jpg
#   inflating: images/8251800811.01.THUMBZZZ.jpg
#   inflating: images/8303025732.01.THUMBZZZ.jpg
#   inflating: images/8306013204.01.THUMBZZZ.jpg
#   inflating: images/8308019188.01.THUMBZZZ.jpg
#   inflating: images/8308029094.01.THUMBZZZ.jpg
#   inflating: images/8308033555.01.THUMBZZZ.jpg
#   inflating: images/8311067406.01.THUMBZZZ.jpg
#   inflating: images/8311068933.01.THUMBZZZ.jpg
#   inflating: images/8320715164.01.THUMBZZZ.jpg
#   inflating: images/8321109640.01.THUMBZZZ.jpg
#   inflating: images/8321329519.01.THUMBZZZ.jpg
#   inflating: images/8321407749.01.THUMBZZZ.jpg
#   inflating: images/832140927X.01.THUMBZZZ.jpg
#   inflating: images/8321728677.01.THUMBZZZ.jpg
#   inflating: images/8321803059.01.THUMBZZZ.jpg
#   inflating: images/8322106491.01.THUMBZZZ.jpg
#   inflating: images/8322319851.01.THUMBZZZ.jpg
#   inflating: images/8370061982.01.THUMBZZZ.jpg
#   inflating: images/837023030X.01.THUMBZZZ.jpg
#   inflating: images/8370237797.01.THUMBZZZ.jpg
#   inflating: images/8370665098.01.THUMBZZZ.jpg
#   inflating: images/8385412565.01.THUMBZZZ.jpg
#   inflating: images/8385496424.01.THUMBZZZ.jpg
#   inflating: images/838694417X.01.THUMBZZZ.jpg
#   inflating: images/8390096420.01.THUMBZZZ.jpg
#   inflating: images/8400000013.01.THUMBZZZ.jpg
#   inflating: images/8401009421.01.THUMBZZZ.jpg
#   inflating: images/8401010918.01.THUMBZZZ.jpg
#   inflating: images/8401011698.01.THUMBZZZ.jpg
#   inflating: images/8401012104.01.THUMBZZZ.jpg
#   inflating: images/8401012201.01.THUMBZZZ.jpg
#   inflating: images/8401012317.01.THUMBZZZ.jpg
#   inflating: images/8401012457.01.THUMBZZZ.jpg
#   inflating: images/840101297X.01.THUMBZZZ.jpg
#   inflating: images/8401013151.01.THUMBZZZ.jpg
#   inflating: images/8401013305.01.THUMBZZZ.jpg
#   inflating: images/8401014239.01.THUMBZZZ.jpg
#   inflating: images/8401014441.01.THUMBZZZ.jpg
#   inflating: images/840101445X.01.THUMBZZZ.jpg
#   inflating: images/8401014549.01.THUMBZZZ.jpg
#   inflating: images/8401014603.01.THUMBZZZ.jpg
#   inflating: images/840101512X.01.THUMBZZZ.jpg
#   inflating: images/840124224X.01.THUMBZZZ.jpg
#   inflating: images/8401242266.01.THUMBZZZ.jpg
#   inflating: images/8401242274.01.THUMBZZZ.jpg
#   inflating: images/8401242304.01.THUMBZZZ.jpg
#   inflating: images/8401242371.01.THUMBZZZ.jpg
#   inflating: images/8401242576.01.THUMBZZZ.jpg
#   inflating: images/840130315X.01.THUMBZZZ.jpg
#   inflating: images/8401304105.01.THUMBZZZ.jpg
#   inflating: images/8401321069.01.THUMBZZZ.jpg
#   inflating: images/8401321182.01.THUMBZZZ.jpg
#   inflating: images/8401321328.01.THUMBZZZ.jpg
#   inflating: images/8401321344.01.THUMBZZZ.jpg
#   inflating: images/840132162X.01.THUMBZZZ.jpg
#   inflating: images/8401321719.01.THUMBZZZ.jpg
#   inflating: images/8401321751.01.THUMBZZZ.jpg
#   inflating: images/8401321786.01.THUMBZZZ.jpg
#   inflating: images/8401321794.01.THUMBZZZ.jpg
#   inflating: images/8401321891.01.THUMBZZZ.jpg
#   inflating: images/8401322626.01.THUMBZZZ.jpg
#   inflating: images/8401322677.01.THUMBZZZ.jpg
#   inflating: images/8401323096.01.THUMBZZZ.jpg
#   inflating: images/8401323460.01.THUMBZZZ.jpg
#   inflating: images/8401323924.01.THUMBZZZ.jpg
#   inflating: images/8401324815.01.THUMBZZZ.jpg
#   inflating: images/8401325218.01.THUMBZZZ.jpg
#   inflating: images/8401326060.01.THUMBZZZ.jpg
#   inflating: images/8401327024.01.THUMBZZZ.jpg
#   inflating: images/8401327148.01.THUMBZZZ.jpg
#   inflating: images/8401327180.01.THUMBZZZ.jpg
#   inflating: images/840132730X.01.THUMBZZZ.jpg
#   inflating: images/8401327504.01.THUMBZZZ.jpg
#   inflating: images/8401327571.01.THUMBZZZ.jpg
#   inflating: images/8401327636.01.THUMBZZZ.jpg
#   inflating: images/8401327857.01.THUMBZZZ.jpg
#   inflating: images/8401327865.01.THUMBZZZ.jpg
#   inflating: images/8401328128.01.THUMBZZZ.jpg
#   inflating: images/8401328136.01.THUMBZZZ.jpg
#   inflating: images/8401328144.01.THUMBZZZ.jpg
#   inflating: images/8401328217.01.THUMBZZZ.jpg
#   inflating: images/8401328241.01.THUMBZZZ.jpg
#   inflating: images/8401328276.01.THUMBZZZ.jpg
#   inflating: images/8401328306.01.THUMBZZZ.jpg
#   inflating: images/8401328667.01.THUMBZZZ.jpg
#   inflating: images/8401328810.01.THUMBZZZ.jpg
#   inflating: images/8401328942.01.THUMBZZZ.jpg
#   inflating: images/8401328977.01.THUMBZZZ.jpg
#   inflating: images/8401328985.01.THUMBZZZ.jpg
#   inflating: images/8401329132.01.THUMBZZZ.jpg
#   inflating: images/8401329280.01.THUMBZZZ.jpg
#   inflating: images/840133165X.01.THUMBZZZ.jpg
#   inflating: images/8401332664.01.THUMBZZZ.jpg
#   inflating: images/8401341507.01.THUMBZZZ.jpg
#   inflating: images/8401341523.01.THUMBZZZ.jpg
#   inflating: images/8401341558.01.THUMBZZZ.jpg
#   inflating: images/8401341574.01.THUMBZZZ.jpg
#   inflating: images/8401341604.01.THUMBZZZ.jpg
#   inflating: images/8401341744.01.THUMBZZZ.jpg
#   inflating: images/8401351545.01.THUMBZZZ.jpg
#   inflating: images/8401351650.01.THUMBZZZ.jpg
#   inflating: images/8401360439.01.THUMBZZZ.jpg
#   inflating: images/8401370361.01.THUMBZZZ.jpg
#   inflating: images/8401370809.01.THUMBZZZ.jpg
#   inflating: images/8401372178.01.THUMBZZZ.jpg
#   inflating: images/8401374618.01.THUMBZZZ.jpg
#   inflating: images/8401375703.01.THUMBZZZ.jpg
#   inflating: images/8401375924.01.THUMBZZZ.jpg
#   inflating: images/8401375932.01.THUMBZZZ.jpg
#   inflating: images/8401376203.01.THUMBZZZ.jpg
#   inflating: images/8401376440.01.THUMBZZZ.jpg
#   inflating: images/8401376513.01.THUMBZZZ.jpg
#   inflating: images/8401376599.01.THUMBZZZ.jpg
#   inflating: images/8401376734.01.THUMBZZZ.jpg
#   inflating: images/8401377013.01.THUMBZZZ.jpg
#   inflating: images/8401377250.01.THUMBZZZ.jpg
#   inflating: images/8401377390.01.THUMBZZZ.jpg
#   inflating: images/8401377617.01.THUMBZZZ.jpg
#   inflating: images/8401377706.01.THUMBZZZ.jpg
#   inflating: images/840138009X.01.THUMBZZZ.jpg
#   inflating: images/8401380111.01.THUMBZZZ.jpg
#   inflating: images/8401380332.01.THUMBZZZ.jpg
#   inflating: images/8401380472.01.THUMBZZZ.jpg
#   inflating: images/840138110X.01.THUMBZZZ.jpg
#   inflating: images/8401381126.01.THUMBZZZ.jpg
#   inflating: images/8401381630.01.THUMBZZZ.jpg
#   inflating: images/8401385008.01.THUMBZZZ.jpg
#   inflating: images/840138527X.01.THUMBZZZ.jpg
#   inflating: images/8401412633.01.THUMBZZZ.jpg
#   inflating: images/8401413117.01.THUMBZZZ.jpg
#   inflating: images/8401413621.01.THUMBZZZ.jpg
#   inflating: images/840141850X.01.THUMBZZZ.jpg
#   inflating: images/8401418569.01.THUMBZZZ.jpg
#   inflating: images/8401418844.01.THUMBZZZ.jpg
#   inflating: images/8401418933.01.THUMBZZZ.jpg
#   inflating: images/8401421101.01.THUMBZZZ.jpg
#   inflating: images/8401421594.01.THUMBZZZ.jpg
#   inflating: images/8401422248.01.THUMBZZZ.jpg
#   inflating: images/8401422515.01.THUMBZZZ.jpg
#   inflating: images/8401422531.01.THUMBZZZ.jpg
#   inflating: images/8401422663.01.THUMBZZZ.jpg
#   inflating: images/8401422701.01.THUMBZZZ.jpg
#   inflating: images/8401422825.01.THUMBZZZ.jpg
#   inflating: images/840142285X.01.THUMBZZZ.jpg
#   inflating: images/8401423007.01.THUMBZZZ.jpg
#   inflating: images/8401423031.01.THUMBZZZ.jpg
#   inflating: images/8401423058.01.THUMBZZZ.jpg
#   inflating: images/8401423201.01.THUMBZZZ.jpg
#   inflating: images/840142321X.01.THUMBZZZ.jpg
#   inflating: images/8401423333.01.THUMBZZZ.jpg
#   inflating: images/8401423465.01.THUMBZZZ.jpg
#   inflating: images/8401423813.01.THUMBZZZ.jpg
#   inflating: images/8401425212.01.THUMBZZZ.jpg
#   inflating: images/8401426111.01.THUMBZZZ.jpg
#   inflating: images/8401426715.01.THUMBZZZ.jpg
#   inflating: images/8401427134.01.THUMBZZZ.jpg
#   inflating: images/8401427150.01.THUMBZZZ.jpg
#   inflating: images/8401427177.01.THUMBZZZ.jpg
#   inflating: images/8401427207.01.THUMBZZZ.jpg
#   inflating: images/8401427517.01.THUMBZZZ.jpg
#   inflating: images/8401427533.01.THUMBZZZ.jpg
#   inflating: images/8401427568.01.THUMBZZZ.jpg
#   inflating: images/8401427762.01.THUMBZZZ.jpg
#   inflating: images/8401428173.01.THUMBZZZ.jpg
#   inflating: images/8401429412.01.THUMBZZZ.jpg
#   inflating: images/8401441226.01.THUMBZZZ.jpg
#   inflating: images/8401442230.01.THUMBZZZ.jpg
#   inflating: images/8401442435.01.THUMBZZZ.jpg
#   inflating: images/8401450381.01.THUMBZZZ.jpg
#   inflating: images/8401450780.01.THUMBZZZ.jpg
#   inflating: images/8401460913.01.THUMBZZZ.jpg
#   inflating: images/8401461170.01.THUMBZZZ.jpg
#   inflating: images/8401461251.01.THUMBZZZ.jpg
#   inflating: images/8401461677.01.THUMBZZZ.jpg
#   inflating: images/8401461715.01.THUMBZZZ.jpg
#   inflating: images/8401461766.01.THUMBZZZ.jpg
#   inflating: images/8401461812.01.THUMBZZZ.jpg
#   inflating: images/840146188X.01.THUMBZZZ.jpg
#   inflating: images/8401462215.01.THUMBZZZ.jpg
#   inflating: images/8401462231.01.THUMBZZZ.jpg
#   inflating: images/8401462924.01.THUMBZZZ.jpg
#   inflating: images/8401463017.01.THUMBZZZ.jpg
#   inflating: images/8401463297.01.THUMBZZZ.jpg
#   inflating: images/8401463327.01.THUMBZZZ.jpg
#   inflating: images/8401463335.01.THUMBZZZ.jpg
#   inflating: images/8401464129.01.THUMBZZZ.jpg
#   inflating: images/8401464625.01.THUMBZZZ.jpg
#   inflating: images/8401465516.01.THUMBZZZ.jpg
#   inflating: images/8401465559.01.THUMBZZZ.jpg
#   inflating: images/8401465583.01.THUMBZZZ.jpg
#   inflating: images/8401466083.01.THUMBZZZ.jpg
#   inflating: images/8401466350.01.THUMBZZZ.jpg
#   inflating: images/8401466369.01.THUMBZZZ.jpg
#   inflating: images/8401467314.01.THUMBZZZ.jpg
#   inflating: images/8401469317.01.THUMBZZZ.jpg
#   inflating: images/840147034X.01.THUMBZZZ.jpg
#   inflating: images/8401472512.01.THUMBZZZ.jpg
#   inflating: images/8401472660.01.THUMBZZZ.jpg
#   inflating: images/840147356X.01.THUMBZZZ.jpg
#   inflating: images/8401473756.01.THUMBZZZ.jpg
#   inflating: images/8401473934.01.THUMBZZZ.jpg
#   inflating: images/8401474523.01.THUMBZZZ.jpg
#   inflating: images/8401474604.01.THUMBZZZ.jpg
#   inflating: images/8401474620.01.THUMBZZZ.jpg
#   inflating: images/8401474655.01.THUMBZZZ.jpg
#   inflating: images/8401474663.01.THUMBZZZ.jpg
#   inflating: images/8401474671.01.THUMBZZZ.jpg
#   inflating: images/840147468X.01.THUMBZZZ.jpg
#   inflating: images/8401474736.01.THUMBZZZ.jpg
#   inflating: images/8401474744.01.THUMBZZZ.jpg
#   inflating: images/8401475546.01.THUMBZZZ.jpg
#   inflating: images/8401476429.01.THUMBZZZ.jpg
#   inflating: images/8401476720.01.THUMBZZZ.jpg
#   inflating: images/8401476798.01.THUMBZZZ.jpg
#   inflating: images/840147812X.01.THUMBZZZ.jpg
#   inflating: images/8401478138.01.THUMBZZZ.jpg
#   inflating: images/840147941X.01.THUMBZZZ.jpg
#   inflating: images/8401479436.01.THUMBZZZ.jpg
#   inflating: images/8401479444.01.THUMBZZZ.jpg
#   inflating: images/8401479452.01.THUMBZZZ.jpg
#   inflating: images/8401479460.01.THUMBZZZ.jpg
#   inflating: images/8401479541.01.THUMBZZZ.jpg
#   inflating: images/840147955X.01.THUMBZZZ.jpg
#   inflating: images/840148569X.01.THUMBZZZ.jpg
#   inflating: images/8401490014.01.THUMBZZZ.jpg
#   inflating: images/8401490286.01.THUMBZZZ.jpg
#   inflating: images/8401490316.01.THUMBZZZ.jpg
#   inflating: images/8401490324.01.THUMBZZZ.jpg
#   inflating: images/8401490618.01.THUMBZZZ.jpg
#   inflating: images/8401490693.01.THUMBZZZ.jpg
#   inflating: images/8401490715.01.THUMBZZZ.jpg
#   inflating: images/8401490979.01.THUMBZZZ.jpg
#   inflating: images/8401490987.01.THUMBZZZ.jpg
#   inflating: images/8401491029.01.THUMBZZZ.jpg
#   inflating: images/8401491061.01.THUMBZZZ.jpg
#   inflating: images/8401491150.01.THUMBZZZ.jpg
#   inflating: images/8401491169.01.THUMBZZZ.jpg
#   inflating: images/8401491363.01.THUMBZZZ.jpg
#   inflating: images/8401491509.01.THUMBZZZ.jpg
#   inflating: images/8401491827.01.THUMBZZZ.jpg
#   inflating: images/8401491843.01.THUMBZZZ.jpg
#   inflating: images/840149186X.01.THUMBZZZ.jpg
#   inflating: images/8401492009.01.THUMBZZZ.jpg
#   inflating: images/8401492041.01.THUMBZZZ.jpg
#   inflating: images/8401492149.01.THUMBZZZ.jpg
#   inflating: images/8401492238.01.THUMBZZZ.jpg
#   inflating: images/8401492335.01.THUMBZZZ.jpg
#   inflating: images/8401492343.01.THUMBZZZ.jpg
#   inflating: images/840149236X.01.THUMBZZZ.jpg
#   inflating: images/8401492521.01.THUMBZZZ.jpg
#   inflating: images/8401492726.01.THUMBZZZ.jpg
#   inflating: images/8401492742.01.THUMBZZZ.jpg
#   inflating: images/840149284X.01.THUMBZZZ.jpg
#   inflating: images/840149303X.01.THUMBZZZ.jpg
#   inflating: images/8401493102.01.THUMBZZZ.jpg
#   inflating: images/8401493129.01.THUMBZZZ.jpg
#   inflating: images/8401493153.01.THUMBZZZ.jpg
#   inflating: images/8401493196.01.THUMBZZZ.jpg
#   inflating: images/8401493234.01.THUMBZZZ.jpg
#   inflating: images/8401493331.01.THUMBZZZ.jpg
#   inflating: images/8401495210.01.THUMBZZZ.jpg
#   inflating: images/8401495229.01.THUMBZZZ.jpg
#   inflating: images/8401495237.01.THUMBZZZ.jpg
#   inflating: images/8401495423.01.THUMBZZZ.jpg
#   inflating: images/8401496063.01.THUMBZZZ.jpg
#   inflating: images/8401496071.01.THUMBZZZ.jpg
#   inflating: images/840149608X.01.THUMBZZZ.jpg
#   inflating: images/8401496128.01.THUMBZZZ.jpg
#   inflating: images/8401496519.01.THUMBZZZ.jpg
#   inflating: images/8401496608.01.THUMBZZZ.jpg
#   inflating: images/8401496616.01.THUMBZZZ.jpg
#   inflating: images/8401496691.01.THUMBZZZ.jpg
#   inflating: images/8401496764.01.THUMBZZZ.jpg
#   inflating: images/8401496772.01.THUMBZZZ.jpg
#   inflating: images/8401496780.01.THUMBZZZ.jpg
#   inflating: images/8401497477.01.THUMBZZZ.jpg
#   inflating: images/8401497639.01.THUMBZZZ.jpg
#   inflating: images/8401497833.01.THUMBZZZ.jpg
#   inflating: images/8401497914.01.THUMBZZZ.jpg
#   inflating: images/8401497922.01.THUMBZZZ.jpg
#   inflating: images/8401498821.01.THUMBZZZ.jpg
#   inflating: images/8401498848.01.THUMBZZZ.jpg
#   inflating: images/8401499046.01.THUMBZZZ.jpg
#   inflating: images/8401499127.01.THUMBZZZ.jpg
#   inflating: images/8401499135.01.THUMBZZZ.jpg
#   inflating: images/8401499143.01.THUMBZZZ.jpg
#   inflating: images/8401499151.01.THUMBZZZ.jpg
#   inflating: images/8401499186.01.THUMBZZZ.jpg
#   inflating: images/8401499216.01.THUMBZZZ.jpg
#   inflating: images/8401499259.01.THUMBZZZ.jpg
#   inflating: images/840149950X.01.THUMBZZZ.jpg
#   inflating: images/8401499534.01.THUMBZZZ.jpg
#   inflating: images/8401499542.01.THUMBZZZ.jpg
#   inflating: images/8401499569.01.THUMBZZZ.jpg
#   inflating: images/8401499577.01.THUMBZZZ.jpg
#   inflating: images/8401499585.01.THUMBZZZ.jpg
#   inflating: images/8401499593.01.THUMBZZZ.jpg
#   inflating: images/840149964X.01.THUMBZZZ.jpg
#   inflating: images/8401499682.01.THUMBZZZ.jpg
#   inflating: images/8401499712.01.THUMBZZZ.jpg
#   inflating: images/840149981X.01.THUMBZZZ.jpg
#   inflating: images/8401499895.01.THUMBZZZ.jpg
#   inflating: images/8401499909.01.THUMBZZZ.jpg
#   inflating: images/8401506557.01.THUMBZZZ.jpg
#   inflating: images/8401517028.01.THUMBZZZ.jpg
#   inflating: images/8401520053.01.THUMBZZZ.jpg
#   inflating: images/8401520509.01.THUMBZZZ.jpg
#   inflating: images/8401530423.01.THUMBZZZ.jpg
#   inflating: images/8401540097.01.THUMBZZZ.jpg
#   inflating: images/8401540968.01.THUMBZZZ.jpg
#   inflating: images/8401540976.01.THUMBZZZ.jpg
#   inflating: images/840154100X.01.THUMBZZZ.jpg
#   inflating: images/8401541034.01.THUMBZZZ.jpg
#   inflating: images/8401541298.01.THUMBZZZ.jpg
#   inflating: images/8401561531.01.THUMBZZZ.jpg
#   inflating: images/8401570506.01.THUMBZZZ.jpg
#   inflating: images/8401570549.01.THUMBZZZ.jpg
#   inflating: images/8401570557.01.THUMBZZZ.jpg
#   inflating: images/8401570689.01.THUMBZZZ.jpg
#   inflating: images/8401590388.01.THUMBZZZ.jpg
#   inflating: images/8401807212.01.THUMBZZZ.jpg
#   inflating: images/8401807220.01.THUMBZZZ.jpg
#   inflating: images/8401807239.01.THUMBZZZ.jpg
#   inflating: images/8402041973.01.THUMBZZZ.jpg
#   inflating: images/8402047831.01.THUMBZZZ.jpg
#   inflating: images/8402048323.01.THUMBZZZ.jpg
#   inflating: images/8402050417.01.THUMBZZZ.jpg
#   inflating: images/840206180X.01.THUMBZZZ.jpg
#   inflating: images/8402062148.01.THUMBZZZ.jpg
#   inflating: images/8402067115.01.THUMBZZZ.jpg
#   inflating: images/8402068812.01.THUMBZZZ.jpg
#   inflating: images/8402068820.01.THUMBZZZ.jpg
#   inflating: images/8402069614.01.THUMBZZZ.jpg
#   inflating: images/8402074685.01.THUMBZZZ.jpg
#   inflating: images/8402082718.01.THUMBZZZ.jpg
#   inflating: images/8402083129.01.THUMBZZZ.jpg
#   inflating: images/840208348X.01.THUMBZZZ.jpg
#   inflating: images/8402097405.01.THUMBZZZ.jpg
#   inflating: images/8403092024.01.THUMBZZZ.jpg
#   inflating: images/8403092148.01.THUMBZZZ.jpg
#   inflating: images/8403092377.01.THUMBZZZ.jpg
#   inflating: images/840309289X.01.THUMBZZZ.jpg
#   inflating: images/8403092903.01.THUMBZZZ.jpg
#   inflating: images/8403092946.01.THUMBZZZ.jpg
#   inflating: images/8403093004.01.THUMBZZZ.jpg
#   inflating: images/8403593902.01.THUMBZZZ.jpg
#   inflating: images/8403594348.01.THUMBZZZ.jpg
#   inflating: images/8403594739.01.THUMBZZZ.jpg
#   inflating: images/8403594984.01.THUMBZZZ.jpg
#   inflating: images/8403595190.01.THUMBZZZ.jpg
#   inflating: images/8403595417.01.THUMBZZZ.jpg
#   inflating: images/8403595425.01.THUMBZZZ.jpg
#   inflating: images/8403596073.01.THUMBZZZ.jpg
#   inflating: images/8403597150.01.THUMBZZZ.jpg
#   inflating: images/8403597223.01.THUMBZZZ.jpg
#   inflating: images/8403597282.01.THUMBZZZ.jpg
#   inflating: images/8403598505.01.THUMBZZZ.jpg
#   inflating: images/8403599072.01.THUMBZZZ.jpg
#   inflating: images/8403599269.01.THUMBZZZ.jpg
#   inflating: images/8403602561.01.THUMBZZZ.jpg
#   inflating: images/840360257X.01.THUMBZZZ.jpg
#   inflating: images/8403602626.01.THUMBZZZ.jpg
#   inflating: images/8403602642.01.THUMBZZZ.jpg
#   inflating: images/8403602693.01.THUMBZZZ.jpg
#   inflating: images/8403602804.01.THUMBZZZ.jpg
#   inflating: images/8408001558.01.THUMBZZZ.jpg
#   inflating: images/840800199X.01.THUMBZZZ.jpg
#   inflating: images/8408002511.01.THUMBZZZ.jpg
#   inflating: images/8408010107.01.THUMBZZZ.jpg
#   inflating: images/840801014X.01.THUMBZZZ.jpg
#   inflating: images/8408010190.01.THUMBZZZ.jpg
#   inflating: images/8408010476.01.THUMBZZZ.jpg
#   inflating: images/8408011200.01.THUMBZZZ.jpg
#   inflating: images/8408011324.01.THUMBZZZ.jpg
#   inflating: images/840801188X.01.THUMBZZZ.jpg
#   inflating: images/8408011979.01.THUMBZZZ.jpg
#   inflating: images/8408012045.01.THUMBZZZ.jpg
#   inflating: images/840801207X.01.THUMBZZZ.jpg
#   inflating: images/8408012290.01.THUMBZZZ.jpg
#   inflating: images/8408012312.01.THUMBZZZ.jpg
#   inflating: images/8408012428.01.THUMBZZZ.jpg
#   inflating: images/8408012436.01.THUMBZZZ.jpg
#   inflating: images/8408012444.01.THUMBZZZ.jpg
#   inflating: images/8408012576.01.THUMBZZZ.jpg
#   inflating: images/8408014102.01.THUMBZZZ.jpg
#   inflating: images/8408014196.01.THUMBZZZ.jpg
#   inflating: images/840801420X.01.THUMBZZZ.jpg
#   inflating: images/8408014692.01.THUMBZZZ.jpg
#   inflating: images/8408014781.01.THUMBZZZ.jpg
#   inflating: images/8408015486.01.THUMBZZZ.jpg
#   inflating: images/8408016059.01.THUMBZZZ.jpg
#   inflating: images/8408016245.01.THUMBZZZ.jpg
#   inflating: images/8408016385.01.THUMBZZZ.jpg
#   inflating: images/8408017136.01.THUMBZZZ.jpg
#   inflating: images/8408017233.01.THUMBZZZ.jpg
#   inflating: images/8408017241.01.THUMBZZZ.jpg
#   inflating: images/8408017748.01.THUMBZZZ.jpg
#   inflating: images/8408017918.01.THUMBZZZ.jpg
#   inflating: images/8408018094.01.THUMBZZZ.jpg
#   inflating: images/840801899X.01.THUMBZZZ.jpg
#   inflating: images/8408019023.01.THUMBZZZ.jpg
#   inflating: images/840801966X.01.THUMBZZZ.jpg
#   inflating: images/8408019899.01.THUMBZZZ.jpg
#   inflating: images/840801997X.01.THUMBZZZ.jpg
#   inflating: images/8408019988.01.THUMBZZZ.jpg
#   inflating: images/8408020013.01.THUMBZZZ.jpg
#   inflating: images/8408020064.01.THUMBZZZ.jpg
#   inflating: images/8408020072.01.THUMBZZZ.jpg
#   inflating: images/8408020080.01.THUMBZZZ.jpg
#   inflating: images/8408020137.01.THUMBZZZ.jpg
#   inflating: images/8408020331.01.THUMBZZZ.jpg
#   inflating: images/8408020366.01.THUMBZZZ.jpg
#   inflating: images/8408020374.01.THUMBZZZ.jpg
#   inflating: images/8408020382.01.THUMBZZZ.jpg
#   inflating: images/8408020390.01.THUMBZZZ.jpg
#   inflating: images/8408020471.01.THUMBZZZ.jpg
#   inflating: images/840802051X.01.THUMBZZZ.jpg
#   inflating: images/8408020811.01.THUMBZZZ.jpg
#   inflating: images/8408020854.01.THUMBZZZ.jpg
#   inflating: images/8408020897.01.THUMBZZZ.jpg
#   inflating: images/8408020935.01.THUMBZZZ.jpg
#   inflating: images/8408020951.01.THUMBZZZ.jpg
#   inflating: images/8408021494.01.THUMBZZZ.jpg
#   inflating: images/8408021915.01.THUMBZZZ.jpg
#   inflating: images/8408022288.01.THUMBZZZ.jpg
#   inflating: images/8408022296.01.THUMBZZZ.jpg
#   inflating: images/8408022393.01.THUMBZZZ.jpg
#   inflating: images/8408022466.01.THUMBZZZ.jpg
#   inflating: images/8408022539.01.THUMBZZZ.jpg
#   inflating: images/8408022547.01.THUMBZZZ.jpg
#   inflating: images/8408022563.01.THUMBZZZ.jpg
#   inflating: images/8408022741.01.THUMBZZZ.jpg
#   inflating: images/8408022792.01.THUMBZZZ.jpg
#   inflating: images/8408022830.01.THUMBZZZ.jpg
#   inflating: images/8408022938.01.THUMBZZZ.jpg
#   inflating: images/8408022946.01.THUMBZZZ.jpg
#   inflating: images/8408023160.01.THUMBZZZ.jpg
#   inflating: images/840802339X.01.THUMBZZZ.jpg
#   inflating: images/8408023624.01.THUMBZZZ.jpg
#   inflating: images/8408023896.01.THUMBZZZ.jpg
#   inflating: images/8408024396.01.THUMBZZZ.jpg
#   inflating: images/8408024485.01.THUMBZZZ.jpg
#   inflating: images/8408024493.01.THUMBZZZ.jpg
#   inflating: images/8408024973.01.THUMBZZZ.jpg
#   inflating: images/8408025325.01.THUMBZZZ.jpg
#   inflating: images/8408025449.01.THUMBZZZ.jpg
#   inflating: images/8408025465.01.THUMBZZZ.jpg
#   inflating: images/8408025945.01.THUMBZZZ.jpg
#   inflating: images/8408026267.01.THUMBZZZ.jpg
#   inflating: images/8408026917.01.THUMBZZZ.jpg
#   inflating: images/8408027190.01.THUMBZZZ.jpg
#   inflating: images/8408027441.01.THUMBZZZ.jpg
#   inflating: images/8408027530.01.THUMBZZZ.jpg
#   inflating: images/8408028472.01.THUMBZZZ.jpg
#   inflating: images/8408028480.01.THUMBZZZ.jpg
#   inflating: images/8408028642.01.THUMBZZZ.jpg
#   inflating: images/8408028944.01.THUMBZZZ.jpg
#   inflating: images/840802910X.01.THUMBZZZ.jpg
#   inflating: images/8408029886.01.THUMBZZZ.jpg
#   inflating: images/8408030566.01.THUMBZZZ.jpg
#   inflating: images/8408030620.01.THUMBZZZ.jpg
#   inflating: images/840803085X.01.THUMBZZZ.jpg
#   inflating: images/840803099X.01.THUMBZZZ.jpg
#   inflating: images/8408031155.01.THUMBZZZ.jpg
#   inflating: images/8408032143.01.THUMBZZZ.jpg
#   inflating: images/8408033700.01.THUMBZZZ.jpg
#   inflating: images/8408033840.01.THUMBZZZ.jpg
#   inflating: images/8408034162.01.THUMBZZZ.jpg
#   inflating: images/8408034618.01.THUMBZZZ.jpg
#   inflating: images/8408034634.01.THUMBZZZ.jpg
#   inflating: images/8408035320.01.THUMBZZZ.jpg
#   inflating: images/8408036408.01.THUMBZZZ.jpg
#   inflating: images/8408036424.01.THUMBZZZ.jpg
#   inflating: images/8408037404.01.THUMBZZZ.jpg
#   inflating: images/8408037919.01.THUMBZZZ.jpg
#   inflating: images/8408038338.01.THUMBZZZ.jpg
#   inflating: images/8408038702.01.THUMBZZZ.jpg
#   inflating: images/8408038745.01.THUMBZZZ.jpg
#   inflating: images/840803880X.01.THUMBZZZ.jpg
#   inflating: images/8408039008.01.THUMBZZZ.jpg
#   inflating: images/840803930X.01.THUMBZZZ.jpg
#   inflating: images/8408039334.01.THUMBZZZ.jpg
#   inflating: images/8408039369.01.THUMBZZZ.jpg
#   inflating: images/8408039636.01.THUMBZZZ.jpg
#   inflating: images/8408039725.01.THUMBZZZ.jpg
#   inflating: images/8408039962.01.THUMBZZZ.jpg
#   inflating: images/8408040235.01.THUMBZZZ.jpg
#   inflating: images/8408040243.01.THUMBZZZ.jpg
#   inflating: images/8408040367.01.THUMBZZZ.jpg
#   inflating: images/8408040391.01.THUMBZZZ.jpg
#   inflating: images/8408040456.01.THUMBZZZ.jpg
#   inflating: images/8408040677.01.THUMBZZZ.jpg
#   inflating: images/8408040685.01.THUMBZZZ.jpg
#   inflating: images/8408040898.01.THUMBZZZ.jpg
#   inflating: images/8408041193.01.THUMBZZZ.jpg
#   inflating: images/8408041770.01.THUMBZZZ.jpg
#   inflating: images/8408041797.01.THUMBZZZ.jpg
#   inflating: images/8408042157.01.THUMBZZZ.jpg
#   inflating: images/8408042467.01.THUMBZZZ.jpg
#   inflating: images/8408043285.01.THUMBZZZ.jpg
#   inflating: images/8408043625.01.THUMBZZZ.jpg
#   inflating: images/8408043641.01.THUMBZZZ.jpg
#   inflating: images/8408043781.01.THUMBZZZ.jpg
#   inflating: images/840804379X.01.THUMBZZZ.jpg
#   inflating: images/8408043862.01.THUMBZZZ.jpg
#   inflating: images/8408044001.01.THUMBZZZ.jpg
#   inflating: images/8408044079.01.THUMBZZZ.jpg
#   inflating: images/8408044141.01.THUMBZZZ.jpg
#   inflating: images/8408044184.01.THUMBZZZ.jpg
#   inflating: images/8408044575.01.THUMBZZZ.jpg
#   inflating: images/8408044656.01.THUMBZZZ.jpg
#   inflating: images/8408045504.01.THUMBZZZ.jpg
#   inflating: images/8408045806.01.THUMBZZZ.jpg
#   inflating: images/840804592X.01.THUMBZZZ.jpg
#   inflating: images/8408046489.01.THUMBZZZ.jpg
#   inflating: images/8408046756.01.THUMBZZZ.jpg
#   inflating: images/8408047310.01.THUMBZZZ.jpg
#   inflating: images/8408047442.01.THUMBZZZ.jpg
#   inflating: images/8408047450.01.THUMBZZZ.jpg
#   inflating: images/8408047957.01.THUMBZZZ.jpg
#   inflating: images/8408047981.01.THUMBZZZ.jpg
#   inflating: images/8408048082.01.THUMBZZZ.jpg
#   inflating: images/8408048368.01.THUMBZZZ.jpg
#   inflating: images/8408048376.01.THUMBZZZ.jpg
#   inflating: images/840804866X.01.THUMBZZZ.jpg
#   inflating: images/8408048945.01.THUMBZZZ.jpg
#   inflating: images/8408048953.01.THUMBZZZ.jpg
#   inflating: images/840804978X.01.THUMBZZZ.jpg
#   inflating: images/8408050044.01.THUMBZZZ.jpg
#   inflating: images/8408050133.01.THUMBZZZ.jpg
#   inflating: images/8408050885.01.THUMBZZZ.jpg
#   inflating: images/8420400025.01.THUMBZZZ.jpg
#   inflating: images/8420400181.01.THUMBZZZ.jpg
#   inflating: images/8420401153.01.THUMBZZZ.jpg
#   inflating: images/8420401552.01.THUMBZZZ.jpg
#   inflating: images/8420421014.01.THUMBZZZ.jpg
#   inflating: images/8420421219.01.THUMBZZZ.jpg
#   inflating: images/8420421480.01.THUMBZZZ.jpg
#   inflating: images/8420421804.01.THUMBZZZ.jpg
#   inflating: images/8420425222.01.THUMBZZZ.jpg
#   inflating: images/8420427462.01.THUMBZZZ.jpg
#   inflating: images/8420427624.01.THUMBZZZ.jpg
#   inflating: images/8420427683.01.THUMBZZZ.jpg
#   inflating: images/8420427845.01.THUMBZZZ.jpg
#   inflating: images/8420428191.01.THUMBZZZ.jpg
#   inflating: images/8420428485.01.THUMBZZZ.jpg
#   inflating: images/8420428655.01.THUMBZZZ.jpg
#   inflating: images/8420428701.01.THUMBZZZ.jpg
#   inflating: images/8420428906.01.THUMBZZZ.jpg
#   inflating: images/8420429031.01.THUMBZZZ.jpg
#   inflating: images/8420429147.01.THUMBZZZ.jpg
#   inflating: images/8420429813.01.THUMBZZZ.jpg
#   inflating: images/8420429872.01.THUMBZZZ.jpg
#   inflating: images/8420429902.01.THUMBZZZ.jpg
#   inflating: images/8420430714.01.THUMBZZZ.jpg
#   inflating: images/8420430773.01.THUMBZZZ.jpg
#   inflating: images/8420430811.01.THUMBZZZ.jpg
#   inflating: images/8420430943.01.THUMBZZZ.jpg
#   inflating: images/8420431249.01.THUMBZZZ.jpg
#   inflating: images/8420432016.01.THUMBZZZ.jpg
#   inflating: images/8420432040.01.THUMBZZZ.jpg
#   inflating: images/8420432113.01.THUMBZZZ.jpg
#   inflating: images/8420432261.01.THUMBZZZ.jpg
#   inflating: images/8420433012.01.THUMBZZZ.jpg
#   inflating: images/8420436143.01.THUMBZZZ.jpg
#   inflating: images/8420439193.01.THUMBZZZ.jpg
#   inflating: images/842043924X.01.THUMBZZZ.jpg
#   inflating: images/8420440620.01.THUMBZZZ.jpg
#   inflating: images/8420440906.01.THUMBZZZ.jpg
#   inflating: images/8420441619.01.THUMBZZZ.jpg
#   inflating: images/8420441694.01.THUMBZZZ.jpg
#   inflating: images/8420441708.01.THUMBZZZ.jpg
#   inflating: images/8420441724.01.THUMBZZZ.jpg
#   inflating: images/8420441872.01.THUMBZZZ.jpg
#   inflating: images/8420441902.01.THUMBZZZ.jpg
#   inflating: images/842044202X.01.THUMBZZZ.jpg
#   inflating: images/8420442089.01.THUMBZZZ.jpg
#   inflating: images/8420442127.01.THUMBZZZ.jpg
#   inflating: images/8420442283.01.THUMBZZZ.jpg
#   inflating: images/8420442313.01.THUMBZZZ.jpg
#   inflating: images/8420442364.01.THUMBZZZ.jpg
#   inflating: images/8420442402.01.THUMBZZZ.jpg
#   inflating: images/8420442569.01.THUMBZZZ.jpg
#   inflating: images/8420442887.01.THUMBZZZ.jpg
#   inflating: images/8420443026.01.THUMBZZZ.jpg
#   inflating: images/8420443107.01.THUMBZZZ.jpg
#   inflating: images/8420444367.01.THUMBZZZ.jpg
#   inflating: images/8420444383.01.THUMBZZZ.jpg
#   inflating: images/8420444642.01.THUMBZZZ.jpg
#   inflating: images/8420444782.01.THUMBZZZ.jpg
#   inflating: images/842044491X.01.THUMBZZZ.jpg
#   inflating: images/8420445479.01.THUMBZZZ.jpg
#   inflating: images/8420445835.01.THUMBZZZ.jpg
#   inflating: images/8420447595.01.THUMBZZZ.jpg
#   inflating: images/8420447625.01.THUMBZZZ.jpg
#   inflating: images/8420447714.01.THUMBZZZ.jpg
#   inflating: images/8420447943.01.THUMBZZZ.jpg
#   inflating: images/842044796X.01.THUMBZZZ.jpg
#   inflating: images/8420447978.01.THUMBZZZ.jpg
#   inflating: images/8420448133.01.THUMBZZZ.jpg
#   inflating: images/8420448435.01.THUMBZZZ.jpg
#   inflating: images/8420448583.01.THUMBZZZ.jpg
#   inflating: images/8420449083.01.THUMBZZZ.jpg
#   inflating: images/8420449091.01.THUMBZZZ.jpg
#   inflating: images/8420449156.01.THUMBZZZ.jpg
#   inflating: images/8420451398.01.THUMBZZZ.jpg
#   inflating: images/842045706X.01.THUMBZZZ.jpg
#   inflating: images/8420457213.01.THUMBZZZ.jpg
#   inflating: images/8420457477.01.THUMBZZZ.jpg
#   inflating: images/8420457663.01.THUMBZZZ.jpg
#   inflating: images/842045804X.01.THUMBZZZ.jpg
#   inflating: images/8420458546.01.THUMBZZZ.jpg
#   inflating: images/842046418X.01.THUMBZZZ.jpg
#   inflating: images/842046435X.01.THUMBZZZ.jpg
#   inflating: images/8420464384.01.THUMBZZZ.jpg
#   inflating: images/8420465534.01.THUMBZZZ.jpg
#   inflating: images/8420465577.01.THUMBZZZ.jpg
#   inflating: images/8420466034.01.THUMBZZZ.jpg
#   inflating: images/8420466557.01.THUMBZZZ.jpg
#   inflating: images/8420466646.01.THUMBZZZ.jpg
#   inflating: images/8420466727.01.THUMBZZZ.jpg
#   inflating: images/8420478407.01.THUMBZZZ.jpg
#   inflating: images/8420478687.01.THUMBZZZ.jpg
#   inflating: images/8420478725.01.THUMBZZZ.jpg
#   inflating: images/8420480509.01.THUMBZZZ.jpg
#   inflating: images/8420480770.01.THUMBZZZ.jpg
#   inflating: images/8420480797.01.THUMBZZZ.jpg
#   inflating: images/8420481017.01.THUMBZZZ.jpg
#   inflating: images/8420481025.01.THUMBZZZ.jpg
#   inflating: images/8420481173.01.THUMBZZZ.jpg
#   inflating: images/8420481289.01.THUMBZZZ.jpg
#   inflating: images/8420481327.01.THUMBZZZ.jpg
#   inflating: images/842048136X.01.THUMBZZZ.jpg
#   inflating: images/8420481378.01.THUMBZZZ.jpg
#   inflating: images/8420481394.01.THUMBZZZ.jpg
#   inflating: images/8420481440.01.THUMBZZZ.jpg
#   inflating: images/8420481610.01.THUMBZZZ.jpg
#   inflating: images/842048170X.01.THUMBZZZ.jpg
#   inflating: images/8420481718.01.THUMBZZZ.jpg
#   inflating: images/8420481793.01.THUMBZZZ.jpg
#   inflating: images/8420481882.01.THUMBZZZ.jpg
#   inflating: images/8420481904.01.THUMBZZZ.jpg
#   inflating: images/8420482013.01.THUMBZZZ.jpg
#   inflating: images/8420482064.01.THUMBZZZ.jpg
#   inflating: images/8420482129.01.THUMBZZZ.jpg
#   inflating: images/8420482277.01.THUMBZZZ.jpg
#   inflating: images/8420482536.01.THUMBZZZ.jpg
#   inflating: images/8420482633.01.THUMBZZZ.jpg
#   inflating: images/8420482684.01.THUMBZZZ.jpg
#   inflating: images/842048301X.01.THUMBZZZ.jpg
#   inflating: images/8420483125.01.THUMBZZZ.jpg
#   inflating: images/8420483508.01.THUMBZZZ.jpg
#   inflating: images/8420483532.01.THUMBZZZ.jpg
#   inflating: images/8420483591.01.THUMBZZZ.jpg
#   inflating: images/8420483834.01.THUMBZZZ.jpg
#   inflating: images/8420483869.01.THUMBZZZ.jpg
#   inflating: images/8420483885.01.THUMBZZZ.jpg
#   inflating: images/8420484385.01.THUMBZZZ.jpg
#   inflating: images/8420484423.01.THUMBZZZ.jpg
#   inflating: images/8420485276.01.THUMBZZZ.jpg
#   inflating: images/8420529869.01.THUMBZZZ.jpg
#   inflating: images/8420530654.01.THUMBZZZ.jpg
#   inflating: images/8420600180.01.THUMBZZZ.jpg
#   inflating: images/8420600296.01.THUMBZZZ.jpg
#   inflating: images/8420600369.01.THUMBZZZ.jpg
#   inflating: images/8420600695.01.THUMBZZZ.jpg
#   inflating: images/8420600814.01.THUMBZZZ.jpg
#   inflating: images/8420601101.01.THUMBZZZ.jpg
#   inflating: images/8420601209.01.THUMBZZZ.jpg
#   inflating: images/842060125X.01.THUMBZZZ.jpg
#   inflating: images/8420601489.01.THUMBZZZ.jpg
#   inflating: images/842060156X.01.THUMBZZZ.jpg
#   inflating: images/8420601748.01.THUMBZZZ.jpg
#   inflating: images/8420601985.01.THUMBZZZ.jpg
#   inflating: images/8420602388.01.THUMBZZZ.jpg
#   inflating: images/8420602647.01.THUMBZZZ.jpg
#   inflating: images/842060321X.01.THUMBZZZ.jpg
#   inflating: images/8420603333.01.THUMBZZZ.jpg
#   inflating: images/8420603775.01.THUMBZZZ.jpg
#   inflating: images/8420604062.01.THUMBZZZ.jpg
#   inflating: images/8420604461.01.THUMBZZZ.jpg
#   inflating: images/8420604666.01.THUMBZZZ.jpg
#   inflating: images/8420604674.01.THUMBZZZ.jpg
#   inflating: images/8420604690.01.THUMBZZZ.jpg
#   inflating: images/8420604852.01.THUMBZZZ.jpg
#   inflating: images/8420605166.01.THUMBZZZ.jpg
#   inflating: images/8420605212.01.THUMBZZZ.jpg
#   inflating: images/842060657X.01.THUMBZZZ.jpg
#   inflating: images/8420606979.01.THUMBZZZ.jpg
#   inflating: images/8420608122.01.THUMBZZZ.jpg
#   inflating: images/8420608246.01.THUMBZZZ.jpg
#   inflating: images/8420610070.01.THUMBZZZ.jpg
#   inflating: images/8420610275.01.THUMBZZZ.jpg
#   inflating: images/8420610445.01.THUMBZZZ.jpg
#   inflating: images/842061050X.01.THUMBZZZ.jpg
#   inflating: images/8420610860.01.THUMBZZZ.jpg
#   inflating: images/8420610925.01.THUMBZZZ.jpg
#   inflating: images/8420611085.01.THUMBZZZ.jpg
#   inflating: images/8420611107.01.THUMBZZZ.jpg
#   inflating: images/8420611131.01.THUMBZZZ.jpg
#   inflating: images/8420611387.01.THUMBZZZ.jpg
#   inflating: images/8420611948.01.THUMBZZZ.jpg
#   inflating: images/8420612693.01.THUMBZZZ.jpg
#   inflating: images/8420612766.01.THUMBZZZ.jpg
#   inflating: images/8420612898.01.THUMBZZZ.jpg
#   inflating: images/8420613096.01.THUMBZZZ.jpg
#   inflating: images/8420613126.01.THUMBZZZ.jpg
#   inflating: images/8420613207.01.THUMBZZZ.jpg
#   inflating: images/8420613460.01.THUMBZZZ.jpg
#   inflating: images/8420613487.01.THUMBZZZ.jpg
#   inflating: images/8420613533.01.THUMBZZZ.jpg
#   inflating: images/8420613819.01.THUMBZZZ.jpg
#   inflating: images/8420614556.01.THUMBZZZ.jpg
#   inflating: images/8420614904.01.THUMBZZZ.jpg
#   inflating: images/8420614998.01.THUMBZZZ.jpg
#   inflating: images/8420615544.01.THUMBZZZ.jpg
#   inflating: images/8420616001.01.THUMBZZZ.jpg
#   inflating: images/8420616028.01.THUMBZZZ.jpg
#   inflating: images/842061615X.01.THUMBZZZ.jpg
#   inflating: images/8420616168.01.THUMBZZZ.jpg
#   inflating: images/8420616230.01.THUMBZZZ.jpg
#   inflating: images/8420616249.01.THUMBZZZ.jpg
#   inflating: images/8420616419.01.THUMBZZZ.jpg
#   inflating: images/8420616621.01.THUMBZZZ.jpg
#   inflating: images/8420616702.01.THUMBZZZ.jpg
#   inflating: images/8420616737.01.THUMBZZZ.jpg
#   inflating: images/8420616893.01.THUMBZZZ.jpg
#   inflating: images/8420617067.01.THUMBZZZ.jpg
#   inflating: images/8420617229.01.THUMBZZZ.jpg
#   inflating: images/8420617350.01.THUMBZZZ.jpg
#   inflating: images/8420617393.01.THUMBZZZ.jpg
#   inflating: images/8420617415.01.THUMBZZZ.jpg
#   inflating: images/8420617458.01.THUMBZZZ.jpg
#   inflating: images/8420617504.01.THUMBZZZ.jpg
#   inflating: images/8420617539.01.THUMBZZZ.jpg
#   inflating: images/8420617725.01.THUMBZZZ.jpg
#   inflating: images/8420618055.01.THUMBZZZ.jpg
#   inflating: images/8420618101.01.THUMBZZZ.jpg
#   inflating: images/8420618187.01.THUMBZZZ.jpg
#   inflating: images/8420618225.01.THUMBZZZ.jpg
#   inflating: images/8420618519.01.THUMBZZZ.jpg
#   inflating: images/8420618578.01.THUMBZZZ.jpg
#   inflating: images/8420618632.01.THUMBZZZ.jpg
#   inflating: images/8420626945.01.THUMBZZZ.jpg
#   inflating: images/8420627232.01.THUMBZZZ.jpg
#   inflating: images/8420628409.01.THUMBZZZ.jpg
#   inflating: images/842063283X.01.THUMBZZZ.jpg
#   inflating: images/8420632848.01.THUMBZZZ.jpg
#   inflating: images/8420632856.01.THUMBZZZ.jpg
#   inflating: images/8420632880.01.THUMBZZZ.jpg
#   inflating: images/8420632899.01.THUMBZZZ.jpg
#   inflating: images/8420632988.01.THUMBZZZ.jpg
#   inflating: images/8420633119.01.THUMBZZZ.jpg
#   inflating: images/8420633127.01.THUMBZZZ.jpg
#   inflating: images/8420633135.01.THUMBZZZ.jpg
#   inflating: images/8420633143.01.THUMBZZZ.jpg
#   inflating: images/8420633178.01.THUMBZZZ.jpg
#   inflating: images/8420633186.01.THUMBZZZ.jpg
#   inflating: images/8420633194.01.THUMBZZZ.jpg
#   inflating: images/8420633224.01.THUMBZZZ.jpg
#   inflating: images/8420633259.01.THUMBZZZ.jpg
#   inflating: images/8420633275.01.THUMBZZZ.jpg
#   inflating: images/8420633291.01.THUMBZZZ.jpg
#   inflating: images/8420633305.01.THUMBZZZ.jpg
#   inflating: images/842063333X.01.THUMBZZZ.jpg
#   inflating: images/8420633356.01.THUMBZZZ.jpg
#   inflating: images/8420633364.01.THUMBZZZ.jpg
#   inflating: images/8420633372.01.THUMBZZZ.jpg
#   inflating: images/8420633380.01.THUMBZZZ.jpg
#   inflating: images/8420633399.01.THUMBZZZ.jpg
#   inflating: images/8420633402.01.THUMBZZZ.jpg
#   inflating: images/8420633410.01.THUMBZZZ.jpg
#   inflating: images/8420633496.01.THUMBZZZ.jpg
#   inflating: images/8420633518.01.THUMBZZZ.jpg
#   inflating: images/8420633526.01.THUMBZZZ.jpg
#   inflating: images/8420633577.01.THUMBZZZ.jpg
#   inflating: images/8420633631.01.THUMBZZZ.jpg
#   inflating: images/8420633925.01.THUMBZZZ.jpg
#   inflating: images/8420633933.01.THUMBZZZ.jpg
#   inflating: images/8420633941.01.THUMBZZZ.jpg
#   inflating: images/8420633976.01.THUMBZZZ.jpg
#   inflating: images/8420634018.01.THUMBZZZ.jpg
#   inflating: images/8420634093.01.THUMBZZZ.jpg
#   inflating: images/8420634115.01.THUMBZZZ.jpg
#   inflating: images/8420634158.01.THUMBZZZ.jpg
#   inflating: images/8420634182.01.THUMBZZZ.jpg
#   inflating: images/8420634190.01.THUMBZZZ.jpg
#   inflating: images/8420634204.01.THUMBZZZ.jpg
#   inflating: images/8420634263.01.THUMBZZZ.jpg
#   inflating: images/8420634433.01.THUMBZZZ.jpg
#   inflating: images/8420634522.01.THUMBZZZ.jpg
#   inflating: images/8420634573.01.THUMBZZZ.jpg
#   inflating: images/842063462X.01.THUMBZZZ.jpg
#   inflating: images/8420634727.01.THUMBZZZ.jpg
#   inflating: images/8420634778.01.THUMBZZZ.jpg
#   inflating: images/8420634972.01.THUMBZZZ.jpg
#   inflating: images/8420635545.01.THUMBZZZ.jpg
#   inflating: images/8420635898.01.THUMBZZZ.jpg
#   inflating: images/8420636258.01.THUMBZZZ.jpg
#   inflating: images/8420636282.01.THUMBZZZ.jpg
#   inflating: images/8420636398.01.THUMBZZZ.jpg
#   inflating: images/8420636592.01.THUMBZZZ.jpg
#   inflating: images/8420636665.01.THUMBZZZ.jpg
#   inflating: images/8420636894.01.THUMBZZZ.jpg
#   inflating: images/8420636940.01.THUMBZZZ.jpg
#   inflating: images/8420637599.01.THUMBZZZ.jpg
#   inflating: images/8420638129.01.THUMBZZZ.jpg
#   inflating: images/8420638188.01.THUMBZZZ.jpg
#   inflating: images/8420638196.01.THUMBZZZ.jpg
#   inflating: images/842063820X.01.THUMBZZZ.jpg
#   inflating: images/8420638218.01.THUMBZZZ.jpg
#   inflating: images/8420638366.01.THUMBZZZ.jpg
#   inflating: images/8420638390.01.THUMBZZZ.jpg
#   inflating: images/8420638412.01.THUMBZZZ.jpg
#   inflating: images/8420638498.01.THUMBZZZ.jpg
#   inflating: images/842063882X.01.THUMBZZZ.jpg
#   inflating: images/8420638900.01.THUMBZZZ.jpg
#   inflating: images/8420639508.01.THUMBZZZ.jpg
#   inflating: images/8420639540.01.THUMBZZZ.jpg
#   inflating: images/8420639567.01.THUMBZZZ.jpg
#   inflating: images/842063977X.01.THUMBZZZ.jpg
#   inflating: images/8420639834.01.THUMBZZZ.jpg
#   inflating: images/8420641227.01.THUMBZZZ.jpg
#   inflating: images/8420644161.01.THUMBZZZ.jpg
#   inflating: images/8420646016.01.THUMBZZZ.jpg
#   inflating: images/8420646024.01.THUMBZZZ.jpg
#   inflating: images/8420646032.01.THUMBZZZ.jpg
#   inflating: images/8420646040.01.THUMBZZZ.jpg
#   inflating: images/8420646067.01.THUMBZZZ.jpg
#   inflating: images/8420646075.01.THUMBZZZ.jpg
#   inflating: images/8420646091.01.THUMBZZZ.jpg
#   inflating: images/8420646105.01.THUMBZZZ.jpg
#   inflating: images/8420646113.01.THUMBZZZ.jpg
#   inflating: images/842064613X.01.THUMBZZZ.jpg
#   inflating: images/8420646148.01.THUMBZZZ.jpg
#   inflating: images/8420646172.01.THUMBZZZ.jpg
#   inflating: images/8420646180.01.THUMBZZZ.jpg
#   inflating: images/8420646199.01.THUMBZZZ.jpg
#   inflating: images/8420646202.01.THUMBZZZ.jpg
#   inflating: images/8420646210.01.THUMBZZZ.jpg
#   inflating: images/8420646237.01.THUMBZZZ.jpg
#   inflating: images/8420646253.01.THUMBZZZ.jpg
#   inflating: images/8420646288.01.THUMBZZZ.jpg
#   inflating: images/8420646296.01.THUMBZZZ.jpg
#   inflating: images/8420646318.01.THUMBZZZ.jpg
#   inflating: images/8420646326.01.THUMBZZZ.jpg
#   inflating: images/8420646334.01.THUMBZZZ.jpg
#   inflating: images/8420646342.01.THUMBZZZ.jpg
#   inflating: images/8420646369.01.THUMBZZZ.jpg
#   inflating: images/8420646407.01.THUMBZZZ.jpg
#   inflating: images/8420646458.01.THUMBZZZ.jpg
#   inflating: images/8420646474.01.THUMBZZZ.jpg
#   inflating: images/842064658X.01.THUMBZZZ.jpg
#   inflating: images/8420646601.01.THUMBZZZ.jpg
#   inflating: images/8420646628.01.THUMBZZZ.jpg
#   inflating: images/8420646636.01.THUMBZZZ.jpg
#   inflating: images/8420646652.01.THUMBZZZ.jpg
#   inflating: images/8420646679.01.THUMBZZZ.jpg
#   inflating: images/8420646709.01.THUMBZZZ.jpg
#   inflating: images/8420646717.01.THUMBZZZ.jpg
#   inflating: images/8420646768.01.THUMBZZZ.jpg
#   inflating: images/8420646865.01.THUMBZZZ.jpg
#   inflating: images/8420646946.01.THUMBZZZ.jpg
#   inflating: images/8420646989.01.THUMBZZZ.jpg
#   inflating: images/8420654426.01.THUMBZZZ.jpg
#   inflating: images/842066104X.01.THUMBZZZ.jpg
#   inflating: images/8420661058.01.THUMBZZZ.jpg
#   inflating: images/8420661066.01.THUMBZZZ.jpg
#   inflating: images/8420670618.01.THUMBZZZ.jpg
#   inflating: images/8420672114.01.THUMBZZZ.jpg
#   inflating: images/8420672211.01.THUMBZZZ.jpg
#   inflating: images/8420672246.01.THUMBZZZ.jpg
#   inflating: images/8420672548.01.THUMBZZZ.jpg
#   inflating: images/8420694762.01.THUMBZZZ.jpg
#   inflating: images/8420698105.01.THUMBZZZ.jpg
#   inflating: images/8420699632.01.THUMBZZZ.jpg
#   inflating: images/8420699853.01.THUMBZZZ.jpg
#   inflating: images/8420699896.01.THUMBZZZ.jpg
#   inflating: images/8420700223.01.THUMBZZZ.jpg
#   inflating: images/8420725897.01.THUMBZZZ.jpg
#   inflating: images/8420725927.01.THUMBZZZ.jpg
#   inflating: images/8420725935.01.THUMBZZZ.jpg
#   inflating: images/8420725943.01.THUMBZZZ.jpg
#   inflating: images/8420726338.01.THUMBZZZ.jpg
#   inflating: images/8420726346.01.THUMBZZZ.jpg
#   inflating: images/8420726583.01.THUMBZZZ.jpg
#   inflating: images/8420726672.01.THUMBZZZ.jpg
#   inflating: images/8420727474.01.THUMBZZZ.jpg
#   inflating: images/8420727946.01.THUMBZZZ.jpg
#   inflating: images/8420727954.01.THUMBZZZ.jpg
# ...
#   inflating: images/970051336X.01.THUMBZZZ.jpg
#   inflating: images/970070629X.01.THUMBZZZ.jpg
#   inflating: images/970651421X.01.THUMBZZZ.jpg
#   inflating: images/970651452X.01.THUMBZZZ.jpg
#   inflating: images/9706611479.01.THUMBZZZ.jpg
#   inflating: images/9706611509.01.THUMBZZZ.jpg
#   inflating: images/9706611622.01.THUMBZZZ.jpg
#   inflating: images/9707012315.01.THUMBZZZ.jpg
#   inflating: images/9707100036.01.THUMBZZZ.jpg
#   inflating: images/9709161512.01.THUMBZZZ.jpg
#   inflating: images/9709187902.01.THUMBZZZ.jpg
#   inflating: images/9710805207.01.THUMBZZZ.jpg
#   inflating: images/9712706370.01.THUMBZZZ.jpg
#   inflating: images/9715420400.01.THUMBZZZ.jpg
#   inflating: images/9715503446.01.THUMBZZZ.jpg
#   inflating: images/9718728015.01.THUMBZZZ.jpg
#   inflating: images/9719110643.01.THUMBZZZ.jpg
#   inflating: images/971911066X.01.THUMBZZZ.jpg
#   inflating: images/9719175672.01.THUMBZZZ.jpg
#   inflating: images/9721013412.01.THUMBZZZ.jpg
#   inflating: images/9721021016.01.THUMBZZZ.jpg
#   inflating: images/9721027758.01.THUMBZZZ.jpg
#   inflating: images/9721030325.01.THUMBZZZ.jpg
#   inflating: images/9721030791.01.THUMBZZZ.jpg
#   inflating: images/9721033596.01.THUMBZZZ.jpg
#   inflating: images/9721035882.01.THUMBZZZ.jpg
#   inflating: images/9721037796.01.THUMBZZZ.jpg
#   inflating: images/9721040169.01.THUMBZZZ.jpg
#   inflating: images/9721045217.01.THUMBZZZ.jpg
#   inflating: images/9722002171.01.THUMBZZZ.jpg
#   inflating: images/9722007009.01.THUMBZZZ.jpg
#   inflating: images/9722007092.01.THUMBZZZ.jpg
#   inflating: images/9722009729.01.THUMBZZZ.jpg
#   inflating: images/9722013343.01.THUMBZZZ.jpg
#   inflating: images/972201398X.01.THUMBZZZ.jpg
#   inflating: images/9722014056.01.THUMBZZZ.jpg
#   inflating: images/9722014862.01.THUMBZZZ.jpg
#   inflating: images/9722016563.01.THUMBZZZ.jpg
#   inflating: images/9722100262.01.THUMBZZZ.jpg
#   inflating: images/9722100408.01.THUMBZZZ.jpg
#   inflating: images/9722100718.01.THUMBZZZ.jpg
#   inflating: images/972210277X.01.THUMBZZZ.jpg
#   inflating: images/9722102869.01.THUMBZZZ.jpg
#   inflating: images/9722102893.01.THUMBZZZ.jpg
#   inflating: images/9722102923.01.THUMBZZZ.jpg
#   inflating: images/972210375X.01.THUMBZZZ.jpg
#   inflating: images/9722104659.01.THUMBZZZ.jpg
#   inflating: images/9722105248.01.THUMBZZZ.jpg
#   inflating: images/9722105329.01.THUMBZZZ.jpg
#   inflating: images/9722105485.01.THUMBZZZ.jpg
#   inflating: images/9722107755.01.THUMBZZZ.jpg
#   inflating: images/9722107909.01.THUMBZZZ.jpg
#   inflating: images/9722108077.01.THUMBZZZ.jpg
#   inflating: images/9722108328.01.THUMBZZZ.jpg
#   inflating: images/9722109030.01.THUMBZZZ.jpg
#   inflating: images/9722109332.01.THUMBZZZ.jpg
#   inflating: images/9722109618.01.THUMBZZZ.jpg
#   inflating: images/972210974X.01.THUMBZZZ.jpg
#   inflating: images/9722110195.01.THUMBZZZ.jpg
#   inflating: images/9722110217.01.THUMBZZZ.jpg
#   inflating: images/9722110500.01.THUMBZZZ.jpg
#   inflating: images/972211137X.01.THUMBZZZ.jpg
#   inflating: images/9722111450.01.THUMBZZZ.jpg
#   inflating: images/9722112384.01.THUMBZZZ.jpg
#   inflating: images/9722112430.01.THUMBZZZ.jpg
#   inflating: images/9722112503.01.THUMBZZZ.jpg
#   inflating: images/9722113666.01.THUMBZZZ.jpg
#   inflating: images/9722212397.01.THUMBZZZ.jpg
#   inflating: images/9722309870.01.THUMBZZZ.jpg
#   inflating: images/9722318179.01.THUMBZZZ.jpg
#   inflating: images/9722504371.01.THUMBZZZ.jpg
#   inflating: images/9722505033.01.THUMBZZZ.jpg
#   inflating: images/9722509713.01.THUMBZZZ.jpg
#   inflating: images/9722706829.01.THUMBZZZ.jpg
#   inflating: images/9722904574.01.THUMBZZZ.jpg
#   inflating: images/9723603306.01.THUMBZZZ.jpg
#   inflating: images/9723605465.01.THUMBZZZ.jpg
#   inflating: images/9723702916.01.THUMBZZZ.jpg
#   inflating: images/9723703661.01.THUMBZZZ.jpg
#   inflating: images/9723704056.01.THUMBZZZ.jpg
#   inflating: images/9723704102.01.THUMBZZZ.jpg
#   inflating: images/9723704242.01.THUMBZZZ.jpg
#   inflating: images/9723704552.01.THUMBZZZ.jpg
#   inflating: images/9724109879.01.THUMBZZZ.jpg
#   inflating: images/9724110141.01.THUMBZZZ.jpg
#   inflating: images/9724111229.01.THUMBZZZ.jpg
#   inflating: images/9724112993.01.THUMBZZZ.jpg
#   inflating: images/9724115380.01.THUMBZZZ.jpg
#   inflating: images/9724116646.01.THUMBZZZ.jpg
#   inflating: images/9724117588.01.THUMBZZZ.jpg
#   inflating: images/9724117812.01.THUMBZZZ.jpg
#   inflating: images/9724119378.01.THUMBZZZ.jpg
#   inflating: images/9724605574.01.THUMBZZZ.jpg
#   inflating: images/972460599X.01.THUMBZZZ.jpg
#   inflating: images/9724606287.01.THUMBZZZ.jpg
#   inflating: images/9724607429.01.THUMBZZZ.jpg
#   inflating: images/9724701131.01.THUMBZZZ.jpg
#   inflating: images/9725502345.01.THUMBZZZ.jpg
#   inflating: images/9725643798.01.THUMBZZZ.jpg
#   inflating: images/9725681398.01.THUMBZZZ.jpg
#   inflating: images/9725681436.01.THUMBZZZ.jpg
#   inflating: images/9725750756.01.THUMBZZZ.jpg
#   inflating: images/9726080045.01.THUMBZZZ.jpg
#   inflating: images/9726100518.01.THUMBZZZ.jpg
#   inflating: images/9726101794.01.THUMBZZZ.jpg
#   inflating: images/9726390001.01.THUMBZZZ.jpg
#   inflating: images/9726672996.01.THUMBZZZ.jpg
#   inflating: images/9726995922.01.THUMBZZZ.jpg
#   inflating: images/9727081479.01.THUMBZZZ.jpg
#   inflating: images/9727091539.01.THUMBZZZ.jpg
#   inflating: images/972711010X.01.THUMBZZZ.jpg
#   inflating: images/9727110800.01.THUMBZZZ.jpg
#   inflating: images/9727110819.01.THUMBZZZ.jpg
#   inflating: images/9727620477.01.THUMBZZZ.jpg
#   inflating: images/972802844X.01.THUMBZZZ.jpg
#   inflating: images/9728028784.01.THUMBZZZ.jpg
#   inflating: images/9728128045.01.THUMBZZZ.jpg
#   inflating: images/9728288115.01.THUMBZZZ.jpg
#   inflating: images/9728423160.01.THUMBZZZ.jpg
#   inflating: images/9728423462.01.THUMBZZZ.jpg
#   inflating: images/9728423853.01.THUMBZZZ.jpg
#   inflating: images/9729013446.01.THUMBZZZ.jpg
#   inflating: images/9729013896.01.THUMBZZZ.jpg
#   inflating: images/9729484309.01.THUMBZZZ.jpg
#   inflating: images/9729484740.01.THUMBZZZ.jpg
#   inflating: images/9739032052.01.THUMBZZZ.jpg
#   inflating: images/973981638X.01.THUMBZZZ.jpg
#   inflating: images/9742020191.01.THUMBZZZ.jpg
#   inflating: images/9742280142.01.THUMBZZZ.jpg
#   inflating: images/9747551675.01.THUMBZZZ.jpg
#   inflating: images/9748237362.01.THUMBZZZ.jpg
#   inflating: images/9748237389.01.THUMBZZZ.jpg
#   inflating: images/9748303292.01.THUMBZZZ.jpg
#   inflating: images/9748303683.01.THUMBZZZ.jpg
#   inflating: images/9748912345.01.THUMBZZZ.jpg
#   inflating: images/9751403707.01.THUMBZZZ.jpg
#   inflating: images/9751407729.01.THUMBZZZ.jpg
#   inflating: images/9757054119.01.THUMBZZZ.jpg
#   inflating: images/9757502006.01.THUMBZZZ.jpg
#   inflating: images/9768108126.01.THUMBZZZ.jpg
#   inflating: images/9768175087.01.THUMBZZZ.jpg
#   inflating: images/9774242335.01.THUMBZZZ.jpg
#   inflating: images/9774244842.01.THUMBZZZ.jpg
#   inflating: images/9796554488.01.THUMBZZZ.jpg
#   inflating: images/9799023386.01.THUMBZZZ.jpg
#   inflating: images/9802570532.01.THUMBZZZ.jpg
#   inflating: images/9802571652.01.THUMBZZZ.jpg
#   inflating: images/9806053443.01.THUMBZZZ.jpg
#   inflating: images/9810023847.01.THUMBZZZ.jpg
#   inflating: images/9810026595.01.THUMBZZZ.jpg
#   inflating: images/9810032439.01.THUMBZZZ.jpg
#   inflating: images/9810035578.01.THUMBZZZ.jpg
#   inflating: images/981013004X.01.THUMBZZZ.jpg
#   inflating: images/9810445911.01.THUMBZZZ.jpg
#   inflating: images/9810446721.01.THUMBZZZ.jpg
#   inflating: images/9810447914.01.THUMBZZZ.jpg
#   inflating: images/9810455674.01.THUMBZZZ.jpg
#   inflating: images/981045645X.01.THUMBZZZ.jpg
#   inflating: images/9810456468.01.THUMBZZZ.jpg
#   inflating: images/9810463952.01.THUMBZZZ.jpg
#   inflating: images/9812046674.01.THUMBZZZ.jpg
#   inflating: images/981204731X.01.THUMBZZZ.jpg
#   inflating: images/9812047883.01.THUMBZZZ.jpg
#   inflating: images/9812180060.01.THUMBZZZ.jpg
#   inflating: images/9812180761.01.THUMBZZZ.jpg
#   inflating: images/9812321764.01.THUMBZZZ.jpg
#   inflating: images/9812325891.01.THUMBZZZ.jpg
#   inflating: images/9812327975.01.THUMBZZZ.jpg
#   inflating: images/9812349502.01.THUMBZZZ.jpg
#   inflating: images/9812349510.01.THUMBZZZ.jpg
#   inflating: images/9813029870.01.THUMBZZZ.jpg
#   inflating: images/981305607X.01.THUMBZZZ.jpg
#   inflating: images/9813056096.01.THUMBZZZ.jpg
#   inflating: images/9813056363.01.THUMBZZZ.jpg
#   inflating: images/9813056398.01.THUMBZZZ.jpg
#   inflating: images/9813056495.01.THUMBZZZ.jpg
#   inflating: images/9813056517.01.THUMBZZZ.jpg
#   inflating: images/9813056576.01.THUMBZZZ.jpg
#   inflating: images/9813056606.01.THUMBZZZ.jpg
#   inflating: images/9813068930.01.THUMBZZZ.jpg
#   inflating: images/9814120383.01.THUMBZZZ.jpg
#   inflating: images/982020125X.01.THUMBZZZ.jpg
#   inflating: images/9831240588.01.THUMBZZZ.jpg
#   inflating: images/9835600570.01.THUMBZZZ.jpg
#   inflating: images/9836225277.01.THUMBZZZ.jpg
#   inflating: images/9836250476.01.THUMBZZZ.jpg
#   inflating: images/9836251804.01.THUMBZZZ.jpg
#   inflating: images/9837407875.01.THUMBZZZ.jpg
#   inflating: images/9838120014.01.THUMBZZZ.jpg
#   inflating: images/9838120200.01.THUMBZZZ.jpg
#   inflating: images/9838120634.01.THUMBZZZ.jpg
#   inflating: images/9838523283.01.THUMBZZZ.jpg
#   inflating: images/9838934445.01.THUMBZZZ.jpg
#   inflating: images/9839154125.01.THUMBZZZ.jpg
#   inflating: images/9839177028.01.THUMBZZZ.jpg
#   inflating: images/9839747231.01.THUMBZZZ.jpg
#   inflating: images/9839950770.01.THUMBZZZ.jpg
#   inflating: images/9839950789.01.THUMBZZZ.jpg
#   inflating: images/9839995006.01.THUMBZZZ.jpg
#   inflating: images/9871106173.01.THUMBZZZ.jpg
#   inflating: images/9871106181.01.THUMBZZZ.jpg
#   inflating: images/9871138008.01.THUMBZZZ.jpg
#   inflating: images/9871138016.01.THUMBZZZ.jpg
#   inflating: images/9871138032.01.THUMBZZZ.jpg
#   inflating: images/9871138148.01.THUMBZZZ.jpg
#   inflating: images/9875400130.01.THUMBZZZ.jpg
#   inflating: images/9875500046.01.THUMBZZZ.jpg
#   inflating: images/9875500534.01.THUMBZZZ.jpg
#   inflating: images/9875500887.01.THUMBZZZ.jpg
#   inflating: images/987550095X.01.THUMBZZZ.jpg
#   inflating: images/9879017056.01.THUMBZZZ.jpg
#   inflating: images/987906500X.01.THUMBZZZ.jpg
#   inflating: images/9879065271.01.THUMBZZZ.jpg
#   inflating: images/9879201116.01.THUMBZZZ.jpg
#   inflating: images/9879332059.01.THUMBZZZ.jpg
#   inflating: images/9879338286.01.THUMBZZZ.jpg
#   inflating: images/9879397274.01.THUMBZZZ.jpg
#   inflating: images/9879402219.01.THUMBZZZ.jpg
#   inflating: images/9879409159.01.THUMBZZZ.jpg
#   inflating: images/9879423224.01.THUMBZZZ.jpg
#   inflating: images/9879423356.01.THUMBZZZ.jpg
#   inflating: images/9879588800.01.THUMBZZZ.jpg
#   inflating: images/987960170X.01.THUMBZZZ.jpg
#   inflating: images/9879630130.01.THUMBZZZ.jpg
#   inflating: images/9879789970.01.THUMBZZZ.jpg
#   inflating: images/9960340112.01.THUMBZZZ.jpg
#   inflating: images/9963842801.01.THUMBZZZ.jpg
#   inflating: images/9968746037.01.THUMBZZZ.jpg
#   inflating: images/996898390X.01.THUMBZZZ.jpg
#   inflating: images/9971400162.01.THUMBZZZ.jpg
#   inflating: images/9971401169.01.THUMBZZZ.jpg
#   inflating: images/9971490242.01.THUMBZZZ.jpg
#   inflating: images/9971640147.01.THUMBZZZ.jpg
#   inflating: images/997164343X.01.THUMBZZZ.jpg
#   inflating: images/9971655373.01.THUMBZZZ.jpg
#   inflating: images/9971692724.01.THUMBZZZ.jpg
#   inflating: images/9972847012.01.THUMBZZZ.jpg
#   inflating: images/9974643058.01.THUMBZZZ.jpg
#   inflating: images/9976100248.01.THUMBZZZ.jpg
#   inflating: images/9976100256.01.THUMBZZZ.jpg
#   inflating: images/9977671281.01.THUMBZZZ.jpg
#   inflating: images/9977986746.01.THUMBZZZ.jpg
#   inflating: images/997951079X.01.THUMBZZZ.jpg
#   inflating: images/9986162823.01.THUMBZZZ.jpg
#   inflating: images/9990371628.01.THUMBZZZ.jpg
#   inflating: images/999058284X.01.THUMBZZZ.jpg
#   inflating: images/9990591199.01.THUMBZZZ.jpg
#   inflating: images/9990984042.01.THUMBZZZ.jpg
#   inflating: images/9991291202.01.THUMBZZZ.jpg
#   inflating: images/9992003766.01.THUMBZZZ.jpg
#   inflating: images/9992059958.01.THUMBZZZ.jpg
#   inflating: images/9992801735.01.THUMBZZZ.jpg
#   inflating: images/9993584185.01.THUMBZZZ.jpg
#   inflating: images/9993677337.01.THUMBZZZ.jpg
#   inflating: images/9994256963.01.THUMBZZZ.jpg
#   inflating: images/9994348337.01.THUMBZZZ.jpg
#   inflating: images/9997405137.01.THUMBZZZ.jpg
#   inflating: images/9997406567.01.THUMBZZZ.jpg
#   inflating: images/9997406990.01.THUMBZZZ.jpg
#   inflating: images/999740923X.01.THUMBZZZ.jpg
#   inflating: images/9997409728.01.THUMBZZZ.jpg
#   inflating: images/9997410440.01.THUMBZZZ.jpg
#   inflating: images/9997411757.01.THUMBZZZ.jpg
#   inflating: images/9997411870.01.THUMBZZZ.jpg
#   inflating: images/9997412044.01.THUMBZZZ.jpg
#   inflating: images/9997412958.01.THUMBZZZ.jpg
#   inflating: images/9997507002.01.THUMBZZZ.jpg
#   inflating: images/999750805X.01.THUMBZZZ.jpg
#   inflating: images/9997508769.01.THUMBZZZ.jpg
#   inflating: images/9997512952.01.THUMBZZZ.jpg
#   inflating: images/9997519086.01.THUMBZZZ.jpg
#   inflating: images/9997520858.01.THUMBZZZ.jpg
#   inflating: images/9997555635.01.THUMBZZZ.jpg
#   inflating: images/9998914140.01.THUMBZZZ.jpg
#   inflating: images/9999980538.01.THUMBZZZ.jpg
#   inflating: images/9999999999.01.THUMBZZZ.jpg
#   inflating: images/B00001IVC7.01.THUMBZZZ.jpg
#   inflating: images/B00001U0CP.01.THUMBZZZ.jpg
#   inflating: images/B0000523SY.01.THUMBZZZ.jpg
#   inflating: images/B00005B4LM.01.THUMBZZZ.jpg
#   inflating: images/B00005N5J6.01.THUMBZZZ.jpg
#   inflating: images/B00005TZWI.01.THUMBZZZ.jpg
#   inflating: images/B00005U7YK.01.THUMBZZZ.jpg
#   inflating: images/B00005UMI4.01.THUMBZZZ.jpg
#   inflating: images/B00005UMK6.01.THUMBZZZ.jpg
#   inflating: images/B0000633PU.01.THUMBZZZ.jpg
#   inflating: images/B000063VMD.01.THUMBZZZ.jpg
#   inflating: images/B00006CRTE.01.THUMBZZZ.jpg
#   inflating: images/B00006H3BO.01.THUMBZZZ.jpg
#   inflating: images/B00006I4OX.01.THUMBZZZ.jpg
#   inflating: images/B00006RGIO.01.THUMBZZZ.jpg
#   inflating: images/B00007FYKW.01.THUMBZZZ.jpg
#   inflating: images/B00007MF56.01.THUMBZZZ.jpg
#   inflating: images/B00008RWPV.01.THUMBZZZ.jpg
#   inflating: images/B000092Q0A.01.THUMBZZZ.jpg
#   inflating: images/B00009EF82.01.THUMBZZZ.jpg
#   inflating: images/B00009MBYK.01.THUMBZZZ.jpg
#   inflating: images/B00009NDAN.01.THUMBZZZ.jpg
#   inflating: images/B0000A2U93.01.THUMBZZZ.jpg
#   inflating: images/B0000AA9JB.01.THUMBZZZ.jpg
#   inflating: images/B0000AZW79.01.THUMBZZZ.jpg
#   inflating: images/B0000C2W5U.01.THUMBZZZ.jpg
#   inflating: images/B0000C7BNG.01.THUMBZZZ.jpg
#   inflating: images/B0000D9PEZ.01.THUMBZZZ.jpg
#   inflating: images/B0000DAOHN.01.THUMBZZZ.jpg
#   inflating: images/B0000DAPP1.01.THUMBZZZ.jpg
#   inflating: images/B0000DYXID.01.THUMBZZZ.jpg
#   inflating: images/B0000E63CJ.01.THUMBZZZ.jpg
#   inflating: images/B0000T6KHI.01.THUMBZZZ.jpg
#   inflating: images/B0000T6KIM.01.THUMBZZZ.jpg
#   inflating: images/B0000VZEH8.01.THUMBZZZ.jpg
#   inflating: images/B0000VZEJQ.01.THUMBZZZ.jpg
#   inflating: images/B0000X8HIE.01.THUMBZZZ.jpg
#   inflating: images/B00011SOXI.01.THUMBZZZ.jpg
#   inflating: images/B00013AX9E.01.THUMBZZZ.jpg
#   inflating: images/B00014WRH4.01.THUMBZZZ.jpg
#   inflating: images/B00019U4II.01.THUMBZZZ.jpg
#   inflating: images/B0001FZGBC.01.THUMBZZZ.jpg
#   inflating: images/B0001FZGPI.01.THUMBZZZ.jpg
#   inflating: images/B0001FZGRQ.01.THUMBZZZ.jpg
#   inflating: images/B0001GMSV2.01.THUMBZZZ.jpg
#   inflating: images/B0001I1KOG.01.THUMBZZZ.jpg
#   inflating: images/B000234N3A.01.THUMBZZZ.jpg
#   inflating: sample_submission.csv
#   inflating: test_ratings.csv
#   inflating: train_ratings.csv
#   inflating: users.csv

# %%
# Out:
# books.csv    images/       sample_submission.csv  train_ratings.csv
# data.tar.gz  sample_data/  test_ratings.csv       users.csv

# %%
path=''

users = pd.read_csv(path+'users.csv')
books = pd.read_csv(path+'books.csv')
ratings = pd.read_csv(path+'train_ratings.csv')

print('users shape: ', users.shape)
print('books shape: ', books.shape)
print('ratings shape: ', ratings.shape)
# Out:
# users shape:  (68092, 3)
# books shape:  (149570, 10)
# ratings shape:  (306795, 3)

# %% [markdown]
# > 1.   users.csv
# > 2.   books.csv
# > 3.   ratings.csv
#
# 순서대로 EDA를 진행해 보겠습니다.
#
# 각 데이터 셋을 열어 데이터를 꼼꼼히 살펴보며 cleaning 을 수행해보고, 간단한 Feature Engineering을 통해 인사이트를 탐색해보겠습니다.

# %% [markdown]
# #(2) users
#
# 사용자의 정보를 담고 있는 파일입니다.
#
# 총 70753 명의 사용자 정보를 담고 있습니다.
#
# `user_id`, `location`, `age` 컬럼으로 구성되어있습니다.
#
# `user_id`는 unique한 값을 나타냅니다.

# %%
users.head()
# Out:
#    user_id                            location   age
# 0        8            timmins, ontario, canada   NaN
# 1    11400             ottawa, ontario, canada  49.0
# 2    11676                       n/a, n/a, n/a   NaN
# 3    67544            toronto, ontario, canada  30.0
# 4    85526  victoria, british columbia, canada  36.0

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68092 entries, 0 to 68091
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   68092 non-null  int64
#  1   location  68092 non-null  object
#  2   age       40259 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.6+ MB

# %%
users.describe().T
# Out:
#            count           mean           std  min       25%       50%  \
# user_id  68092.0  139381.329539  80523.969862  8.0  69008.75  138845.5
# age      40259.0      36.069873     13.842571  5.0     25.00      34.0
#
#                75%       max
# user_id  209388.25  278854.0
# age          45.00      99.0

# %%
users['user_id'].nunique()
# Out:
# 68092

# %%
users.isna().sum()/len(users)
# Out:
# user_id     0.000000
# location    0.000000
# age         0.408756
# dtype: float64

# %% [markdown]
# age에 많은 결측값이 있는 것을 확인할 수 있습니다.

# %% [markdown]
# ## (2-1) Preprocessing & Feature Engineering
#
# 현재 `location` 칼럼에는 지역, 주, 국가 순서로 모든 정보가 다 들어와있습니다.
#
# 이를 전처리를 통해 각각 컬럼으로 분리하는 과정을 거치겠습니다.

# %%
users['location'] = users['location'].str.replace(r'[^0-9a-zA-Z:,]', '') # 특수문자 제거

users['location_city'] = users['location'].apply(lambda x: x.split(',')[0].strip())
users['location_state'] = users['location'].apply(lambda x: x.split(',')[1].strip())
users['location_country'] = users['location'].apply(lambda x: x.split(',')[2].strip())

users = users.replace('na', np.nan) #특수문자 제거로 n/a가 na로 바뀌게 되었습니다. 따라서 이를 컴퓨터가 인식할 수 있는 결측값으로 변환합니다.
users = users.replace('', np.nan) # 일부 경우 , , ,으로 입력된 경우가 있었으므로 이런 경우에도 결측값으로 변환합니다.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
users.head()
# Out:
#    user_id                         location   age location_city  \
# 0        8           timmins,ontario,canada   NaN       timmins
# 1    11400            ottawa,ontario,canada  49.0        ottawa
# 2    11676                         na,na,na   NaN           NaN
# 3    67544           toronto,ontario,canada  30.0       toronto
# 4    85526  victoria,britishcolumbia,canada  36.0      victoria
#
#     location_state location_country
# 0          ontario           canada
# 1          ontario           canada
# 2              NaN              NaN
# 3          ontario           canada
# 4  britishcolumbia           canada

# %%
users.isna().sum()
# Out:
# user_id                 0
# location                0
# age                 27833
# location_city         122
# location_state       3254
# location_country     2124
# dtype: int64

# %%
users[users['location_country'].isna()]
# Out:
#        user_id        location   age location_city location_state  \
# 2        11676        na,na,na   NaN           NaN            NaN
# 6       116866        ottawa,,   NaN        ottawa            NaN
# 32      115097       seattle,,  27.0       seattle            NaN
# 49      245827   albuquerque,,   NaN   albuquerque            NaN
# 72      226745        humble,,  38.0        humble            NaN
# ...        ...             ...   ...           ...            ...
# 67797   257311   lisbon,maine,  36.0        lisbon          maine
# 67929   267240       houston,,   NaN       houston            NaN
# 67930   267276     sammamish,,   NaN     sammamish            NaN
# 68058   276221       calgary,,   NaN       calgary            NaN
# 68068   276949  bolligen,bern,  24.0      bolligen           bern
#
#       location_country
# 2                  NaN
# 6                  NaN
# 32                 NaN
# 49                 NaN
# 72                 NaN
# ...                ...
# 67797              NaN
# 67929              NaN
# 67930              NaN
# 68058              NaN
# 68068              NaN
#
# [2124 rows x 6 columns]

# %% [markdown]
# country가 결측값인 일부 행을 살펴보면 city값이 존재하는데, country 정보가 없는 경우가 있습니다.
#
# 따라서 이런 경우를 처리해주도록 하겠습니다.

# %%
modify_location = users[(users['location_country'].isna())&(users['location_city'].notnull())]['location_city'].values
location = users[(users['location'].str.contains('seattle'))&(users['location_country'].notnull())]['location'].value_counts().index[0]

location_list = []
for location in modify_location:
    try:
        right_location = users[(users['location'].str.contains(location))&(users['location_country'].notnull())]['location'].value_counts().index[0]
        location_list.append(right_location)
    except:
        pass

# %%
for location in location_list:
    users.loc[users[users['location_city']==location.split(',')[0]].index,'location_state'] = location.split(',')[1]
    users.loc[users[users['location_city']==location.split(',')[0]].index,'location_country'] = location.split(',')[2]

# %%
users.isna().sum()
# Out:
# user_id                 0
# location                0
# age                 27833
# location_city         122
# location_state       1132
# location_country      271
# dtype: int64

# %% [markdown]
# location_state와 location_country의 결측값이 줄어든 것을 확인할 수 있습니다.

# %% [markdown]
# ## (2-2) 시각화
# 데이터 시각화를 통해 사용자들의 나이 분포, 거주 국가 등을 알아보겠습니다.

# %%
# 나이 분포
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

users['age'].hist(bins=40, color='teal', ax=ax[0])
sns.boxenplot(data=users, x='age', color='teal',ax=ax[1])

plt.show()

# %%
users['age'].value_counts()
# Out:
# 29.0    1290
# 26.0    1250
# 25.0    1243
# 34.0    1215
# 27.0    1207
#         ...
# 86.0       1
# 94.0       1
# 89.0       1
# 98.0       1
# 92.0       1
# Name: age, Length: 91, dtype: int64

# %%
users['age'].nunique()
# Out:
# 91

# %%
plt.figure(figsize=(30,5))
users['age'].value_counts().sort_index().plot(kind='bar')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# 20대 초반 ~ 30대 중반까지의 사용자가 많은 것을 확인할 수 있습니다.
#
# 이번에는 사용자들의 거주 국가를 살펴보고 국가별로 사용자의 분포가 다른지 알아보겠습니다.

# %%
my_dict=(users['location_country'].value_counts()).to_dict()
count= pd.DataFrame(list(my_dict.items()),columns = ['location_country','count'])
f = count.sort_values(by=['count'], ascending = False)
f = f.head(15)
# f.drop(7,inplace=True)
fig=plt.figure(figsize=(11,6))
ax = sns.barplot(y = 'count',x= 'location_country' , data = f)
ax.set_xticklabels(ax.get_xticklabels(), rotation=60,horizontalalignment='center')
for bar in ax.patches: 
    ax.annotate(format(bar.get_height(), '.0f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=8, xytext=(0,8), 
                   textcoords='offset points') 

plt.xlabel("Country", size=10)
plt.ylabel("# of Users", size=10)
plt.show()

# %% [markdown]
# 사용자의 대다수는 미국에 거주중인 것을 확인할 수 있습니다.
#
# 국가별 사용자의 나이대를 알아보겠습니다.

# %%
fig, ax = plt.subplots(3,5,figsize=(20,8))
for country, ax_ in zip(f['location_country'], ax.flatten()):
    users[(users['location_country']==country)]['age'].value_counts().sort_index().plot(ax=ax_, title=country)
plt.xlim(0,100)
plt.tight_layout()
plt.show()

# %% [markdown]
# 대부분 20~30대 사용자가 많지만, 국가별로 사용자의 분포가 약간씩 차이가 있는 것을 확인할 수 있습니다.

# %% [markdown]
# age의 결측값을 살펴보겠습니다.

# %%
users[users['age'].isna()]['location_country'].value_counts()
# Out:
# usa                  20214
# canada                3139
# germany               1105
# unitedkingdom          958
# australia              477
#                      ...
# unitedstaes              1
# missouri                 1
# unknown                  1
# dominicanrepublic        1
# macedonia                1
# Name: location_country, Length: 177, dtype: int64

# %%
my_dict=(users[users['age'].isna()]['location_country'].value_counts()).to_dict()
count= pd.DataFrame(list(my_dict.items()),columns = ['location_country','count'])
f = count.sort_values(by=['count'], ascending = False)
f = f.head(15)
fig=plt.figure(figsize=(11,6))
ax = sns.barplot(y = 'count',x= 'location_country' , data = f)
ax.set_xticklabels(ax.get_xticklabels(), rotation=60,horizontalalignment='center')
for bar in ax.patches: 
    ax.annotate(format(bar.get_height(), '.0f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=8, xytext=(0,8), 
                   textcoords='offset points') 

plt.xlabel("Country", size=10)
plt.ylabel("# of Users", size=10)
plt.show()

# %% [markdown]
# 위의 그래프와 큰 차이가 없는 점을 고려했을때, 특정국가에 몰려있다기 보단 골고루 결측치가 퍼져 있다고 판단할 수 있습니다.
#
# 국가별 평균, 중앙값, 최빈값 등을 넣어볼수도 있고, 국가별로 큰 나이분포에 큰 차이가 없다고 판단한 경우 전체의 통계치로 채울 수도 있습니다.
#
# 또는 결측값을 평균, 중앙값, 최빈값 등의 값으로 채우지 않고 결측값 자체로 가져가는 방법도 있습니다.
#
# 다양한 방법을 시도해보시기 바랍니다.

# %%
# users = users.drop(columns='location')

# %% [markdown]
# # (3) books
# 이제 책에 대한 정보를 살펴보겠습니다.
#
# `isbn`, `book_title`, `book_author`, `year_of_publication`, `publisher`, `img_s', `img_m`, `img_l`, `language`, `category` 칼럼으로 이뤄져있습니다.
#
# `isbn`은 책의 고유 코드를 나타냅니다
#
# 같은 title을 가진 책이더라도 발행 년도, 출판사, 언어 등에 따라 책 코드가 다를 수 있습니다.

# %%
books.shape
# Out:
# (149570, 10)

# %%
books['isbn'].nunique()
# Out:
# 149570

# %%
books['book_title'].nunique()
# Out:
# 135436

# %%
books.head()
# Out:
#          isbn                                         book_title  \
# 0  0002005018                                       Clara Callan
# 1  0060973129                               Decision in Normandy
# 2  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3  0399135782                             The Kitchen God's Wife
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#             book_author  year_of_publication                 publisher  \
# 0  Richard Bruce Wright               2001.0     HarperFlamingo Canada
# 1          Carlo D'Este               1991.0           HarperPerennial
# 2      Gina Bari Kolata               1999.0      Farrar Straus Giroux
# 3               Amy Tan               1991.0          Putnam Pub Group
# 4         Robert Cowley               2000.0  Berkley Publishing Group
#
#                                              img_url language       category  \
# 0  http://images.amazon.com/images/P/0002005018.0...       en  ['Actresses']
# 1  http://images.amazon.com/images/P/0060973129.0...       en  ['1940-1949']
# 2  http://images.amazon.com/images/P/0374157065.0...       en    ['Medical']
# 3  http://images.amazon.com/images/P/0399135782.0...       en    ['Fiction']
# 4  http://images.amazon.com/images/P/0425176428.0...       en    ['History']
#
#                                              summary  \
# 0  In a small town in Canada, Clara Callan reluct...
# 1  Here, for the first time in paperback, is an o...
# 2  Describes the great flu epidemic of 1918, an o...
# 3  A Chinese immigrant who is convinced she is dy...
# 4  Essays by respected military historians, inclu...
#
#                             img_path
# 0  images/0002005018.01.THUMBZZZ.jpg
# 1  images/0060973129.01.THUMBZZZ.jpg
# 2  images/0374157065.01.THUMBZZZ.jpg
# 3  images/0399135782.01.THUMBZZZ.jpg
# 4  images/0425176428.01.THUMBZZZ.jpg

# %%
books.isna().sum() #language, category, summary에 결측값이 있습니다
# Out:
# isbn                       0
# book_title                 0
# book_author                0
# year_of_publication        0
# publisher                  0
# img_url                    0
# language               67227
# category               68851
# summary                67227
# img_path                   0
# dtype: int64

# %%
books[books['language'].isna() & books['summary'].notnull()]
# Out:
# Empty DataFrame
# Columns: [isbn, book_title, book_author, year_of_publication, publisher, img_url, language, category, summary, img_path]
# Index: []

# %%
books[books['language'].notnull() & books['summary'].isna()]
# Out:
# Empty DataFrame
# Columns: [isbn, book_title, book_author, year_of_publication, publisher, img_url, language, category, summary, img_path]
# Index: []

# %%
books[books['language'].isna() & books['category'].notnull()]
# Out:
# Empty DataFrame
# Columns: [isbn, book_title, book_author, year_of_publication, publisher, img_url, language, category, summary, img_path]
# Index: []

# %%
books[books['language'].notnull() & books['category'].isna()]
# Out:
#               isbn                                         book_title  \
# 138     2070567842        Folio Junior: L'histoire De Monsieur Sommer
# 193     3596292646                Das Buch der lÃ?Â¤cherlichen Liebe.
# 486     0871131811                           Zodiac: The Eco-Thriller
# 880     067144378X                                         SABLE MOON
# 1001    0345339711     The Two Towers (The Lord of the Rings, Part 2)
# ...            ...                                                ...
# 149252  3770401697  Lucky Luke, Bd.58, Die Geister-Ranch und ander...
# 149307  0806917695  Perplexing Lateral Thinking Puzzles: Scholasti...
# 149329  3426192543    Im FrÃ?Â¼hling singt zum letztenmal die Lerche.
# 149441  2253054615                                        Le maharani
# 149529  0812531558                                         Tweedlioop
#
#                   book_author  year_of_publication                 publisher  \
# 138            Su>skind-Sempe               1994.0        Gallimard-Jeunesse
# 193             Milan Kundera               2000.0  Fischer (Tb.), Frankfurt
# 486           Neal Stephenson               1988.0            Pub Group West
# 880            Nancy Springer               1981.0                    Pocket
# 1001           J.R.R. TOLKIEN               1986.0                   Del Rey
# ...                       ...                  ...                       ...
# 149252         Michel Janvier               1989.0      Egmont Ehapa, Berlin
# 149307            Paul Sloane               1997.0       Sterling Publishing
# 149329  Johannes Mario Simmel               1990.0             Droemer Knaur
# 149441             Gita Mehta               1990.0                       LGF
# 149529        Stanley Schmidt               1988.0        St. Martin's Press
#
#                                                   img_url language category  \
# 138     http://images.amazon.com/images/P/2070567842.0...       fr      NaN
# 193     http://images.amazon.com/images/P/3596292646.0...       de      NaN
# 486     http://images.amazon.com/images/P/0871131811.0...       en      NaN
# 880     http://images.amazon.com/images/P/067144378X.0...       en      NaN
# 1001    http://images.amazon.com/images/P/0345339711.0...       en      NaN
# ...                                                   ...      ...      ...
# 149252  http://images.amazon.com/images/P/3770401697.0...       de      NaN
# 149307  http://images.amazon.com/images/P/0806917695.0...       en      NaN
# 149329  http://images.amazon.com/images/P/3426192543.0...       de      NaN
# 149441  http://images.amazon.com/images/P/2253054615.0...       fr      NaN
# 149529  http://images.amazon.com/images/P/0812531558.0...       en      NaN
#
#                                                   summary  \
# 138     Un petit garçon se pose énormément de question...
# 193     Die im &#39;Buch der lächerlichen Liebe&#39; v...
# 486     Sangamon Taylor, an environmental extremist, s...
# 880     Seventeen-year-old Prince Trevyn must save the...
# 1001    Thus continues the magnificent, bestselling ta...
# ...                                                   ...
# 149252  Enth. noch: Die Hellseherin, Die Statue und Di...
# 149307  Normal situations veer off into the bizarre, c...
# 149329  Eine Gruppe von Idealisten nimmt den Kampf geg...
# 149441  Elevée à la cour comme toutes les maharani l&#...
# 149529  But the government wanted Tweedlioop the alien...
#
#                                  img_path
# 138     images/2070567842.01.THUMBZZZ.jpg
# 193     images/3596292646.01.THUMBZZZ.jpg
# 486     images/0871131811.01.THUMBZZZ.jpg
# 880     images/067144378X.01.THUMBZZZ.jpg
# 1001    images/0345339711.01.THUMBZZZ.jpg
# ...                                   ...
# 149252  images/3770401697.01.THUMBZZZ.jpg
# 149307  images/0806917695.01.THUMBZZZ.jpg
# 149329  images/3426192543.01.THUMBZZZ.jpg
# 149441  images/2253054615.01.THUMBZZZ.jpg
# 149529  images/0812531558.01.THUMBZZZ.jpg
#
# [1624 rows x 10 columns]

# %% [markdown]
# language는 있지만 category가 결측인 경우는 존재합니다.
#
# language가 결측값인 경우, summary도 결측값인 것을 확인할 수 있습니다.

# %% [markdown]
# ## (3-1) Preprocessing & Feature Engineering
#
# books의 경우 데이터를 다양한 방법으로 수정하여 여러 테스트를 해볼 수 있을 것으로 예상됩니다.
#
# 본 미션의 내용 이외에 다양한 시도를 해보고 성능을 측정해보시기 바랍니다.

# %% [markdown]
# ### (3-1-1) isbn
#
# 먼저 isbn과 img_url, img_path의 연관성을 찾을 수 있습니다.
#
# `isbn`과 img_path, img_url 모두 동일한지 살펴보는 작업을 거치고 isbn의 성질을 이용하여 전처리를 진행해보겠습니다.

# %%
books[books['isbn'] != books['img_url'].apply(lambda x: x.split('P/')[1][:10])]
# Out:
# Empty DataFrame
# Columns: [isbn, book_title, book_author, year_of_publication, publisher, img_url, language, category, summary, img_path]
# Index: []

# %%
books[books['isbn']!=books['img_path'].apply(lambda x: x.split('/')[1][:10])]
# Out:
# Empty DataFrame
# Columns: [isbn, book_title, book_author, year_of_publication, publisher, img_url, language, category, summary, img_path]
# Index: []

# %% [markdown]
# 모두 동일하여 추가적인 작업이 필요없음을 확인했습니다.

# %% [markdown]
# isbn은 책의 개별적인 고유번호를 나타내는 10자리 숫자입니다.
#
# 출판 국가, 출판사 번호, 항목 번호, 확인 숫자 순서로 구성되며 확인 숫자의 경우 10을 나타내는 X가 오기도 합니다.
#
# 이 번호를 활용하여 출판사의 항목 갯수를 줄여보도록 하겠습니다.

# %%
publisher_dict=(books['publisher'].value_counts()).to_dict()
publisher_count_df= pd.DataFrame(list(publisher_dict.items()),columns = ['publisher','count'])

publisher_count_df = publisher_count_df.sort_values(by=['count'], ascending = False)

# %%
publisher_count_df.head()
# Out:
#           publisher  count
# 0         Harlequin   3005
# 1  Ballantine Books   2322
# 2            Pocket   2274
# 3     Penguin Books   1943
# 4      Bantam Books   1938

# %%
books[books['publisher']=="Penguin Books"]
# Out:
#               isbn                                         book_title  \
# 68      0140067477                                    The Tao of Pooh
# 119     0143034359  Thursday Next in the Well Of Lost Plots (Thurs...
# 157     0140250964                                        Snow Angels
# 196     0140272100                                           Vanished
# 298     014028009X                              Bridget Jones's Diary
# ...            ...                                                ...
# 149154  0140423818      Lord Byron: Selected Poems (Penguin Classics)
# 149301  0140290788                Time Out Chicago (Time Out Chicago)
# 149345  0140182551        The Old Wives' Tale (20th Century Classics)
# 149387  0140390715                   The Pathfinder (Penguin Classic)
# 149471  0140134212  House of glass: A novel (Penguin international...
#
#                   book_author  year_of_publication      publisher  \
# 68              Benjamin Hoff               1983.0  Penguin Books
# 119             Fforde Jasper               2004.0  Penguin Books
# 157             Stewart O'Nan               1995.0  Penguin Books
# 196       Mary McGarry Morris               1997.0  Penguin Books
# 298            Helen Fielding               1999.0  Penguin Books
# ...                       ...                  ...            ...
# 149154    George Gordon Byron               1996.0  Penguin Books
# 149301               Time Out               2000.0  Penguin Books
# 149345         Arnold Bennett               1990.0  Penguin Books
# 149387  James Fenimore Cooper               1989.0  Penguin Books
# 149471  Pramoedya Ananta Toer               1992.0  Penguin Books
#
#                                                   img_url language  \
# 68      http://images.amazon.com/images/P/0140067477.0...       en
# 119     http://images.amazon.com/images/P/0143034359.0...       en
# 157     http://images.amazon.com/images/P/0140250964.0...       en
# 196     http://images.amazon.com/images/P/0140272100.0...       en
# 298     http://images.amazon.com/images/P/014028009X.0...       en
# ...                                                   ...      ...
# 149154  http://images.amazon.com/images/P/0140423818.0...       en
# 149301  http://images.amazon.com/images/P/0140290788.0...      NaN
# 149345  http://images.amazon.com/images/P/0140182551.0...       en
# 149387  http://images.amazon.com/images/P/0140390715.0...       en
# 149471  http://images.amazon.com/images/P/0140134212.0...      NaN
#
#            category                                            summary  \
# 68        ['Humor']  An expert in Chinese philosophy explains facet...
# 119     ['Fiction']  Exhausted by her stint as Miss Havisham&#39;s ...
# 157     ['Fiction']  Weaves together two stories in the account of ...
# 196     ['Fiction']  Aubrey Wallace is the kind of man no one notices.
# 298     ['Fiction']  This witty national bestseller is now availabl...
# ...             ...                                                ...
# 149154   ['Poetry']  &quot; &quot;Byron&#39;s contemporary populari...
# 149301          NaN                                                NaN
# 149345  ['Fiction']  Victorian novel set in the pottery district of...
# 149387  ['Fiction']  Cooper undertakes a &quot;hazardous experiment...
# 149471          NaN                                                NaN
#
#                                  img_path
# 68      images/0140067477.01.THUMBZZZ.jpg
# 119     images/0143034359.01.THUMBZZZ.jpg
# 157     images/0140250964.01.THUMBZZZ.jpg
# 196     images/0140272100.01.THUMBZZZ.jpg
# 298     images/014028009X.01.THUMBZZZ.jpg
# ...                                   ...
# 149154  images/0140423818.01.THUMBZZZ.jpg
# 149301  images/0140290788.01.THUMBZZZ.jpg
# 149345  images/0140182551.01.THUMBZZZ.jpg
# 149387  images/0140390715.01.THUMBZZZ.jpg
# 149471  images/0140134212.01.THUMBZZZ.jpg
#
# [1943 rows x 10 columns]

# %% [markdown]
# 유명출판사를 조회하여 보면 isbn의 시작이 모두 0140으로 시작하는 것을 확인할 수있습니다.
#
# 그러나 표기 방법의 차이 및 오타로 인해 같은 그룹으로 묶이지 못하는 항목이 있습니다.
#
# 이런 항목을 수정해보겠습니다.

# %%
books['publisher'].nunique() # 수정전 항목 수를 확인합니다.
# Out:
# 11571

# %%
books[books['isbn'].apply(lambda x: x[:4])=='0140']['publisher'].unique()
# Out:
# array(['Penguin Books', 'Penguin Books Ltd', 'Puffin Books',
#        'Penguin USA (Paper)', 'Penguin USA', 'Puffin',
#        'Penguin Putnam~trade', 'Penguin Putnam~mass',
#        'Penguin/Puffin Mass Market (Mm)', 'Viking Books',
#        'Penguin Books Australia Ltd', 'Penguin Uk',
#        'Scott Foresman (Pearson K-12)',
#        'Penguin Putnam Books for Young Readers',
#        'French & European Pubns', 'Viking Penguin', 'Arkana',
#        'Penguin Highbridge Audio', 'Penguin (Non-Classics)',
#        'Penguin Books, Limited (UK)', 'Viking Press', 'Penguin U S A',
#        'Penguin/Puffin Mass Market', 'Select Penguin (Mm)',
#        'Penguin Putnam', 'Penguin Books India', 'Select Penguin',
#        'Penguin Books Australia Ltd.', 'Viking Penguin Inc',
#        'Penguin Audiobooks', 'Studio Books', 'Penguin',
#        'Hyperion Books for Children', 'Putnam Pub Group', 'Penguin India',
#        'Compass Books', 'Penguin Putnam~childrens Hc',
#        'Penguin in association with Secker and Warburg', 'Time Out',
#        'Perennial', 'Viking Juvenile', 'Virago Press', 'South Asia Books',
#        'RoC', 'Penguin Books Canada Ltd', 'Penguin Books (NZ) Ltd',
#        'Ballantine Books', 'Outlet', 'Penguin USA (J)', 'Books Britain',
#        'Speak', 'Penguin USA (P)', 'Penguin Books / Granta',
#        'Granta Books', 'Trafalgar Square Publishing', 'Vintage Books',
#        'Penguin Highbridge', 'Intl Center for Creative Thinking',
#        'Penguin Group USA', 'Time Out Publishing', 'Penguin Books (NZ)',
#        'Pelican Publishing Company', 'Pearson Schools', 'Dutton Books',
#        'Viking Studio', 'Penguin Books Canada',
#        'Granta Books in association with Penguin Books', 'Terra Nova Pr'],
#       dtype=object)

# %%
modify_list = publisher_count_df[publisher_count_df['count']>1].publisher.values

# %%
for publisher in modify_list:
    try:
        number = books[books['publisher']==publisher]['isbn'].apply(lambda x: x[:4]).value_counts().index[0]
        right_publisher = books[books['isbn'].apply(lambda x: x[:4])==number]['publisher'].value_counts().index[0]
        books.loc[books[books['isbn'].apply(lambda x: x[:4])==number].index,'publisher'] = right_publisher
    except: 
        pass

# %%
books['publisher'].nunique() #수정 후 출판사 갯수입니다
# Out:
# 1523

# %% [markdown]
# ### (3-1-2) Category
#
# category를 칼럼의 항목을 대괄호 밖으로 빼는 과정을 거친 뒤 어떤 category가 있는지 살펴보겠습니다

# %%
import re
books.loc[books[books['category'].notnull()].index, 'category'] = books[books['category'].notnull()]['category'].apply(lambda x: re.sub('[\W_]+',' ',x).strip())

# %%
books['category'].value_counts()
# Out:
# Fiction                                            32956
# Juvenile Fiction                                    5804
# Biography Autobiography                             3320
# History                                             1925
# Religion                                            1818
#                                                    ...
# Eschatology                                            1
# Dogsledding                                            1
# Brenner Simon Fictitious character                     1
# Gone with the wind Motion picture 1939                 1
# Authors Canadian English 20th century Biography        1
# Name: category, Length: 4137, dtype: int64

# %%
books['category'] = books['category'].str.lower()

# %%
books['category'].value_counts()
# Out:
# fiction                                            33016
# juvenile fiction                                    5835
# biography autobiography                             3326
# history                                             1927
# religion                                            1818
#                                                    ...
# brenner simon fictitious character                     1
# gone with the wind motion picture 1939                 1
# disguise                                               1
# country lawyers                                        1
# authors canadian english 20th century biography        1
# Name: category, Length: 4105, dtype: int64

# %%
category_df = pd.DataFrame(books['category'].value_counts()).reset_index()
category_df.columns = ['category','count']
category_df.head()
# Out:
#                   category  count
# 0                  fiction  33016
# 1         juvenile fiction   5835
# 2  biography autobiography   3326
# 3                  history   1927
# 4                 religion   1818

# %%
category_df[category_df['count']>=10]
# Out:
#                       category  count
# 0                      fiction  33016
# 1             juvenile fiction   5835
# 2      biography autobiography   3326
# 3                      history   1927
# 4                     religion   1818
# ..                         ...    ...
# 253  children s poetry english     10
# 254            abused children     10
# 255                    courage     10
# 256              diary fiction     10
# 257            spanish fiction     10
#
# [258 rows x 2 columns]

# %% [markdown]
# 카테고리를 보면 3000개가 넘는 종류를 갖고 있습니다.
#
# 그러나 이 중 10개 이상의 중복을 갖는 카테고리가 50개가 안되는것을 통해, 많은 카테고리가 그룹화 안된 채로 존재한다고 볼 수 있습니다.
#
# 또한 일부 카테고리의 경우 전기&자서전 카테고리와 전기, 자서전 이렇게 나눠져 있는 경우가 있습니다.
#
# 이러한 카테고리를 좀더 큰 카테고리로 묶어주는 과정을 시도하여 카테고리의 가짓수를 줄일 수 있습니다.
#
# 본 과정은 여러분들이 EDA를 진행하는 과정에서 더 많은 시도를 해볼 수 있을 것으로 생각됩니다.
#
#
# 상위 카테고리를 만들어보겠습니다.

# %%
books['category_high'] = books['category'].copy()
books.loc[books[books['category']=='biography'].index, 'category_high'] = 'biography autobiography'
books.loc[books[books['category']=='autobiography'].index,'category_high'] = 'biography autobiography'

# %% [markdown]
# 하나씩 찾아서 변경하기엔 너무 많은 자료양을 갖고 있습니다.
#
# 따라서 이런식으로 해당 단어를 포함하는 경우 전체를 바꿀 수 있습니다.

# %%
books[books['category'].str.contains('history', na=False)]['category'].unique()
# Out:
# array(['history', 'oral history', 'natural history', 'history modern',
#        'world history', 'politics history 1945', 'history asia',
#        'church history', 'constitutional history'], dtype=object)

# %%
books.loc[books[books['category'].str.contains('history',na=False)].index,'category_high'] = 'history'

# %% [markdown]
# 이렇게 바꾸기에도 방대한 양을 가지고 있으므로 반복문을 통해 몇가지 카테고리들을 처리하는 예시를 보여드리겠습니다.

# %%
categories = ['garden','crafts','physics','adventure','music','fiction','nonfiction','science','science fiction','social','homicide',
 'sociology','disease','religion','christian','philosophy','psycholog','mathemat','agricult','environmental',
 'business','poetry','drama','literary','travel','motion picture','children','cook','literature','electronic',
 'humor','animal','bird','photograph','computer','house','ecology','family','architect','camp','criminal','language','india']

for category in categories:
    books.loc[books[books['category'].str.contains(category,na=False)].index,'category_high'] = category

# %%
category_high_df = pd.DataFrame(books['category_high'].value_counts()).reset_index()
category_high_df.columns = ['category','count']
category_high_df.head(10)
# Out:
#                   category  count
# 0                  fiction  39678
# 1  biography autobiography   3335
# 2                  history   1949
# 3                 religion   1824
# 4               nonfiction   1427
# 5                    humor   1291
# 6                   social   1271
# 7                 business   1146
# 8                     cook   1125
# 9         body mind spirit   1113

# %%
# 5개 이하인 항목은 others로 묶어주도록 하겠습니다.
others_list = category_high_df[category_high_df['count']<5]['category'].values

# %%
books.loc[books[books['category_high'].isin(others_list)].index, 'category_high']='others'

# %%
books['category'].nunique()
# Out:
# 4105

# %%
books['category_high'].nunique()
# Out:
# 412

# %% [markdown]
# 이런식으로 category 가지수를 줄일 수 있습니다.

# %%
books.isna().sum()
# Out:
# isbn                       0
# book_title                 0
# book_author                0
# year_of_publication        0
# publisher                  0
# img_url                    0
# language               67227
# category               68851
# summary                67227
# img_path                   0
# category_high          68851
# dtype: int64

# %% [markdown]
# 데이터를 살펴보다 보면 아래처럼 같은 책으로 여겨지는 항목이 있는 경우가 있습니다.
#
# 그러나 책의 고유 번호인 isbn이 다르고, 출판사가 다르므로 설령 같은 책이여도, 다른 국가에서 출판됐을 가능성을 배재할 수 없으므로 language를 채우는 것은 어려워보입니다.
#
# 물론, 0446365505 책의 category_high를 fiction으로 수정하는 작업은 해볼 수 있습니다.
#
# 뒤의 작업들을 해보면서 category 항목이 중요하다고 여겨지면, 좀더 시간을 들여서 상위 카테고리 지정하여 데이터 전처리 수준을 올릴 수 있을 것입니다.

# %%
books[books['book_title'].str.contains("Pleading Guilty")]
# Out:
#              isbn                                         book_title  \
# 5041   0446365505                                    Pleading Guilty
# 22680  0816157464  Pleading Guilty (G K Hall Large Print Book Ser...
# 37056  0374234574                                    Pleading Guilty
#
#        book_author  year_of_publication             publisher  \
# 5041   Scott Turow               1994.0          Warner Books
# 22680  Scott Turow               1993.0  Troll Communications
# 37056  Scott Turow               1993.0  Farrar Straus Giroux
#
#                                                  img_url language category  \
# 5041   http://images.amazon.com/images/P/0446365505.0...      NaN      NaN
# 22680  http://images.amazon.com/images/P/0816157464.0...      NaN      NaN
# 37056  http://images.amazon.com/images/P/0374234574.0...       en  fiction
#
#                                                  summary  \
# 5041                                                 NaN
# 22680                                                NaN
# 37056  Immediately. Turow&#39;s third novel takes us ...
#
#                                 img_path category_high
# 5041   images/0446365505.01.THUMBZZZ.jpg           NaN
# 22680  images/0816157464.01.THUMBZZZ.jpg           NaN
# 37056  images/0374234574.01.THUMBZZZ.jpg       fiction

# %% [markdown]
# ## (3-2) 시각화
# - 이미지 url 활용
#
# 이번에는 이미지를 살펴보겠습니다.
# 먼저 url를 이용해서 이미지를 불러오는 방법을 알아보겠습니다.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import requests

# %%
books[books['book_title'].str.contains('Harry')]
# Out:
#               isbn                                         book_title  \
# 390     0439064864   Harry Potter and the Chamber of Secrets (Book 2)
# 391     0439064872   Harry Potter and the Chamber of Secrets (Book 2)
# 392     0439136350  Harry Potter and the Prisoner of Azkaban (Book 3)
# 393     0439136369  Harry Potter and the Prisoner of Azkaban (Book 3)
# 394     0439139597       Harry Potter and the Goblet of Fire (Book 4)
# ...            ...                                                ...
# 140403  0743202430  Eleanor and Harry : The Correspondence of Elea...
# 142947  0972322108  The Hidden Key to Harry Potter: Understanding ...
# 143065  0743223748  Harry and Ike: The Partnership That Remade the...
# 145141  3895849618  Harry Potter und der Gefangene von Askaban. So...
# 147880  0819308854                      Horseshoe Harry and the Whale
#
#               book_author  year_of_publication                  publisher  \
# 390         J. K. Rowling               1999.0                 Scholastic
# 391         J. K. Rowling               2000.0                 Scholastic
# 392         J. K. Rowling               1999.0                 Scholastic
# 393         J. K. Rowling               2001.0                 Scholastic
# 394         J. K. Rowling               2000.0                 Scholastic
# ...                   ...                  ...                        ...
# 140403  Eleanor Roosevelt               2002.0                     Pocket
# 142947       John Granger               2002.0  Global Authors Publishers
# 143065         Steve Neal               2002.0                     Pocket
# 145141  Joanne K. Rowling               2002.0                   Konemann
# 147880     Adele De Leeuw               1976.0     Parents Magazine Press
#
#                                                   img_url language  \
# 390     http://images.amazon.com/images/P/0439064864.0...       en
# 391     http://images.amazon.com/images/P/0439064872.0...      NaN
# 392     http://images.amazon.com/images/P/0439136350.0...       en
# 393     http://images.amazon.com/images/P/0439136369.0...      NaN
# 394     http://images.amazon.com/images/P/0439139597.0...       en
# ...                                                   ...      ...
# 140403  http://images.amazon.com/images/P/0743202430.0...      NaN
# 142947  http://images.amazon.com/images/P/0972322108.0...       en
# 143065  http://images.amazon.com/images/P/0743223748.0...       en
# 145141  http://images.amazon.com/images/P/3895849618.0...      NaN
# 147880  http://images.amazon.com/images/P/0819308854.0...      NaN
#
#                        category  \
# 390            juvenile fiction
# 391                         NaN
# 392            juvenile fiction
# 393                         NaN
# 394            juvenile fiction
# ...                         ...
# 140403                      NaN
# 142947                 children
# 143065  biography autobiography
# 145141                      NaN
# 147880                      NaN
#
#                                                   summary  \
# 390     In Harry Potter and the Chamber of Secrets, th...
# 391                                                   NaN
# 392     During his third year at Hogwarts School for w...
# 393                                                   NaN
# 394     The fourth title in the continuing saga includ...
# ...                                                   ...
# 140403                                                NaN
# 142947  The Hidden Key to Harry Potter is the first bo...
# 143065  In the first biography to examine in depth the...
# 145141                                                NaN
# 147880                                                NaN
#
#                                  img_path            category_high
# 390     images/0439064864.01.THUMBZZZ.jpg                  fiction
# 391     images/0439064872.01.THUMBZZZ.jpg                      NaN
# 392     images/0439136350.01.THUMBZZZ.jpg                  fiction
# 393     images/0439136369.01.THUMBZZZ.jpg                      NaN
# 394     images/0439139597.01.THUMBZZZ.jpg                  fiction
# ...                                   ...                      ...
# 140403  images/0743202430.01.THUMBZZZ.jpg                      NaN
# 142947  images/0972322108.01.THUMBZZZ.jpg                 children
# 143065  images/0743223748.01.THUMBZZZ.jpg  biography autobiography
# 145141  images/3895849618.01.THUMBZZZ.jpg                      NaN
# 147880  images/0819308854.01.THUMBZZZ.jpg                      NaN
#
# [180 rows x 11 columns]

# %%
fig= plt.plot(figsize=(3,4))
url = books['img_url'][284]
img = np.asarray(Image.open(requests.get(url, stream=True).raw))
plt.axis("off")
plt.imshow(img)

# %%
parameters = {
          'axes.titlesize': 10}
plt.rcParams.update(parameters)

# %%
fig, ax = plt.subplots(2, 5, figsize=(20, 10)) 
for i, ax in zip(range(282, 292), ax.flatten()):
    url = books['img_url'][i]
    img = np.asarray(Image.open(requests.get(url, stream=True).raw))
    ax.imshow(img)
    ax.axis("off")
 
    ax.set_title(books['book_title'][i])

fig.show()

# %% [markdown]
# - img path 활용
#
# img 파일을 활용해서 불러오는 방법을 알아보겠습니다.

# %% [markdown]
# zip 파일을 열고, 관련있는 데이터만 가져와서 사용하겠습니다.

# %%
import zipfile
import os

# %%
# !wget --load-cookies ~/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies ~/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=19Y56g8oGQyUWhrRkjeSeP_ZJvHKRUzbn' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=19Y56g8oGQyUWhrRkjeSeP_ZJvHKRUzbn" -O images.zip && rm -rf ~/cookies.txt

# %%
# images_zip = zipfile.ZipFile('/content/images.zip')
# images_zip.extractall('/content/images')

# %%
ls
# Out:
# books.csv    images/       sample_submission.csv  train_ratings.csv
# data.tar.gz  sample_data/  test_ratings.csv       users.csv

# %%
fig, ax = plt.subplots(2, 5, figsize=(20, 10)) 
image_path = ''
for i, ax in zip(range(280, 290), ax.flatten()):
    file_path = image_path+books['img_path'][i]
    img = np.asarray(Image.open(file_path))
    ax.imshow(img)
    ax.axis("off")
 
    ax.set_title(books['book_title'][i])

fig.show()

# %% [markdown]
# - 그 외 시각화

# %%
books['publisher'].value_counts().head(10)
# Out:
# Pocket                7306
# Harlequin             5268
# Bantam Books          4815
# St. Martin's Press    4043
# Vintage Books USA     3822
# Penguin Books         3807
# Perennial             3313
# Ballantine Books      3090
# Signet Book           3068
# Avon                  2792
# Name: publisher, dtype: int64

# %%
publisher_dict=(books['publisher'].value_counts()).to_dict()
publisher_count_df= pd.DataFrame(list(publisher_dict.items()),columns = ['publisher','count'])

b = publisher_count_df.sort_values(by=['count'], ascending = False)
b = b.head(20)

fig=plt.figure(figsize=(10,7))
ax = sns.barplot(x = 'count',y = 'publisher' , data = b)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90,horizontalalignment='center')
plt.xlabel("No of Books Published", size=14)
plt.ylabel("Publisher", size=14)
plt.title(" Top 20 Publishers With the Most Books", size=18)

plt.show()

# %%
print(sorted(books['year_of_publication'].unique()),end=' ')
# Out:
# [1376.0, 1378.0, 1806.0, 1900.0, 1901.0, 1902.0, 1904.0, 1906.0, 1908.0, 1911.0, 1920.0, 1923.0, 1924.0, 1925.0, 1926.0, 1927.0, 1928.0, 1929.0, 1930.0, 1931.0, 1932.0, 1933.0, 1934.0, 1935.0, 1936.0, 1937.0, 1938.0, 1939.0, 1940.0, 1941.0, 1942.0, 1943.0, 1944.0, 1945.0, 1946.0, 1947.0, 1948.0, 1949.0, 1950.0, 1951.0, 1952.0, 1953.0, 1954.0, 1955.0, 1956.0, 1957.0, 1958.0, 1959.0, 1960.0, 1961.0, 1962.0, 1963.0, 1964.0, 1965.0, 1966.0, 1967.0, 1968.0, 1969.0, 1970.0, 1971.0, 1972.0, 1973.0, 1974.0, 1975.0, 1976.0, 1977.0, 1978.0, 1979.0, 1980.0, 1981.0, 1982.0, 1983.0, 1984.0, 1985.0, 1986.0, 1987.0, 1988.0, 1989.0, 1990.0, 1991.0, 1992.0, 1993.0, 1994.0, 1995.0, 1996.0, 1997.0, 1998.0, 1999.0, 2000.0, 2001.0, 2002.0, 2003.0, 2004.0, 2005.0, 2006.0]

# %% [markdown]
# 1900~2001년까지 출간된 책이 존재하고 있습니다.

# %%
plt.figure(figsize=(10,5))
sns.histplot(books['year_of_publication'],bins=100)
plt.xlabel('year_of_publication',size=14)
plt.title('Histogram of the year_of_publication',size=16)
plt.show()

# %%
books['year_of_publication'].value_counts().sort_index()
# Out:
# 1376.0        1
# 1378.0        1
# 1806.0        1
# 1900.0        1
# 1901.0        4
#           ...
# 2002.0    11669
# 2003.0     9430
# 2004.0     3771
# 2005.0       19
# 2006.0        1
# Name: year_of_publication, Length: 95, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.histplot(books[books['year_of_publication']>1960]['year_of_publication'],bins=41)
plt.xlabel('year_of_publication',size=14)
plt.title('Histogram of the year_of_publication',size=16)
plt.show()

# %% [markdown]
# 1970년 이전의 책은 몇권 없는 것을 확인할 수 있습니다.
#
# 데이터의 책들은 1990년 이후의 책이 대다수입니다.

# %% [markdown]
# # (4) ratings
#
# ratings 파일은 사용자가 특정 책을 읽고 점수를 매긴 데이터 입니다.
#
#  `user_id`, `isbn`, `rating` 으로 이뤄져있습니다.
#
#  한 사용자가 다른 책을 여러번 읽기 때문에 중복된 값이 나타나게 되지만,
#
#  users에 있는 모든 사용자가 포함된 데이터입니다.

# %%
ratings.head()
# Out:
#    user_id        isbn  rating
# 0        8  0002005018       4
# 1    67544  0002005018       7
# 2   123629  0002005018       8
# 3   200273  0002005018       8
# 4   210926  0002005018       9

# %%
ratings['user_id'].nunique()
# Out:
# 59803

# %%
ratings.shape
# Out:
# (306795, 3)

# %%
ratings
# Out:
#         user_id        isbn  rating
# 0             8  0002005018       4
# 1         67544  0002005018       7
# 2        123629  0002005018       8
# 3        200273  0002005018       8
# 4        210926  0002005018       9
# ...         ...         ...     ...
# 306790   278843  0743525493       7
# 306791   278851  067161746X       6
# 306792   278851  0884159221       7
# 306793   278851  0912333022       7
# 306794   278851  1569661057      10
#
# [306795 rows x 3 columns]

# %%
ratings['rating'].value_counts(True)
# Out:
# 8     0.239877
# 7     0.172519
# 9     0.158650
# 10    0.139422
# 6     0.082501
# 5     0.045995
# 1     0.043185
# 2     0.042142
# 4     0.041419
# 3     0.034290
# Name: rating, dtype: float64

# %% [markdown]
# rating은 1~10값을 가지며 1이 가장 많습니다.
#
# 총 70753명의 사용자들이 평가한 정보가 있습니다.

# %% [markdown]
# ## (4-1) 시각화

# %%
#유저당 몇 권 정도의 책을 읽었는지 살펴보겠습니다.
ratings.groupby('user_id')['rating'].count().sort_values(ascending=False)
# Out:
# user_id
# 11676     5520
# 98391     4560
# 189835    1503
# 153662    1496
# 23902      956
#           ...
# 47317        1
# 150670       1
# 150676       1
# 150677       1
# 138957       1
# Name: rating, Length: 59803, dtype: int64

# %% [markdown]
# 유저는 1권에서 6538권까지 책을 읽은 것으로 보입니다.
#
# 많은 책을 읽은 유저들의 rating 분포와 그렇지 않은 유저들의 분포를 살펴보겠습니다.

# %%
heavy_users_list = ratings.groupby('user_id')['rating'].count().sort_values(ascending=False).head(20).index

# %%
ratings[ratings['user_id'].isin(heavy_users_list)].groupby('user_id')['rating'].mean()
# Out:
# user_id
# 11676     6.779891
# 16795     6.423684
# 23902     7.174686
# 35859     7.175896
# 56399     9.312036
# 76499     8.477778
# 95359     7.200820
# 98391     8.566228
# 101851    8.420354
# 114368    4.364389
# 153662    8.209893
# 158295    5.770270
# 171118    6.961089
# 177458    6.757794
# 182085    8.210269
# 185233    3.263914
# 189835    3.184298
# 197659    8.116170
# 235105    7.713054
# 248718    7.419009
# Name: rating, dtype: float64

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12, 8))
sns.countplot(data=ratings[(ratings['user_id'].isin(heavy_users_list))&(ratings['rating']>1)] , x='rating', palette='rocket_r')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12, 8))
sns.countplot(data=ratings[~(ratings['user_id'].isin(heavy_users_list))&(ratings['rating']>1)] , x='rating', palette='rocket_r')
plt.show()

# %% [markdown]
# heavy 유저들이 상대적으로 10점을 잘 안주는 것으로 보여집니다.
#
# 이번에는 가장 인기 있는 책은 몇번 읽혔는지 알아보겠습니다.

# %%
ratings.groupby('isbn')['rating'].count().sort_values(ascending=False)
# Out:
# isbn
# 0316666343    566
# 0971880107    465
# 0385504209    390
# 0312195516    307
# 0060928336    256
#              ...
# 0520060199      1
# 0520059808      1
# 0520058852      1
# 0520058763      1
# B000234N3A      1
# Name: rating, Length: 129777, dtype: int64

# %% [markdown]
# 가장 인기있는 책은 2502번 읽혔습니다.
#
# 데이터 merge 이후 해당 책이 무엇인지 알아보겠습니다.
#
# **현재 점수는 1~10점으로 분류되어 있으며 1점이 가장 많습니다. --> 이거 다름**

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12, 8))
sns.countplot(data=ratings , x='rating', palette='rocket_r')
plt.show()

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12, 8))
sns.countplot(data=ratings[(ratings['rating']>1)] , x='rating', palette='rocket_r')
plt.show()

# %% [markdown]
# # (5) 파일 merge
#
# 이제 세 파일을 모두 합쳐서 컬럼간의 관계를 살펴보도록 하겠습니다.

# %%
merge1 = ratings.merge(books, how='left', on='isbn')
data = merge1.merge(users, how='inner', on='user_id')
print('merge 결과 shape: ', data.shape)
# Out:
# merge 결과 shape:  (306795, 17)

# %%
ratings.shape
# ratings 기록 갯수만큼 결과가 나온것을 확인 할 수 있습니다.
# Out:
# (306795, 3)

# %%
set(ratings['isbn']) - set(books['isbn'])
# Out:
# set()

# %% [markdown]
# ## (5-1) 시각화

# %%
popular_book_list = data['book_title'].value_counts().sort_values(ascending=False)[:30].index
popular_book = data[data['book_title'].isin(popular_book_list)]

# %%
fig, ax1 = plt.subplots(figsize=(20,6))
plt.xticks(rotation=80)
sns.lineplot(data = popular_book,x='book_title',y='rating' ,marker='o', estimator=np.median, ax=ax1)
ax2 = ax1.twinx()

sns.countplot(data=popular_book, x='book_title', alpha=0.5, ax=ax2)
plt.show()

# %%
popular_book_list = data['isbn'].value_counts().sort_values(ascending=False)[:30].index
popular_book = data[data['isbn'].isin(popular_book_list)]

fig, ax1 = plt.subplots(figsize=(20,6))
plt.xticks(rotation=80)
sns.lineplot(data = popular_book,x='book_title',y='rating' ,marker='o', estimator=np.median, ax=ax1)
ax2 = ax1.twinx()

sns.countplot(data=popular_book, x='book_title', alpha=0.5, ax=ax2)
plt.show()

# %% [markdown]
# book_title을 사용했을때와 isbn을 사용한 결과에 차이가 있는 것을 볼 수 있습니다.
#
# 이는 isbn이 책 고유번호로써 특정 국가에서 인기 차이가 반영되기 때문이라고 생각할 수 있습니다.
#
# 또한 가장 많이 읽힌 책이 오히려 median 및 평균이 낮은 것을 확인 할 수 있는데 이는 rating 1이 많아서 그런것일수도 있으므로 이를 제외해 보겠습니다.

# %%
# book title을 사용했을떄
popular_book_list = data['book_title'].value_counts().sort_values(ascending=False)[:30].index
popular_book = data[data['book_title'].isin(popular_book_list)]
fig, ax1 = plt.subplots(2,1, figsize=(20,6))
plt.xticks(rotation=80)
plot1 = sns.lineplot(data = popular_book,x='book_title',y='rating' ,marker='o', estimator=np.median, ax=ax1[0])
plot1 = sns.countplot(data=popular_book, x='book_title', alpha=0.5, ax=ax1[0].twinx())
plot1.set_xticklabels([])


plot2 = sns.lineplot(data = popular_book[popular_book['rating']>1],x='book_title',y='rating' ,marker='o', estimator=np.median, ax=ax1[1])
plot2 = sns.countplot(data=popular_book[popular_book['rating']>1], x='book_title', alpha=0.5, ax=ax1[1].twinx())
plt.show()

# %%
# isbn을 사용했을 때
popular_book_list = data['isbn'].value_counts().sort_values(ascending=False)[:30].index
popular_book = data[data['isbn'].isin(popular_book_list)]
fig, ax1 = plt.subplots(2,1, figsize=(20,6))
plt.xticks(rotation=80)
plot1 = sns.lineplot(data=popular_book,x='book_title',y='rating' ,marker='o', estimator=np.median, ax=ax1[0])
plot1 = sns.countplot(data=popular_book, x='book_title', alpha=0.5, ax=ax1[0].twinx())
plot1.set_xticklabels([])

plot2 = sns.lineplot(data = popular_book[popular_book['rating']>1],x='book_title',y='rating' ,marker='o', estimator=np.median, ax=ax1[1])
plot2 = sns.countplot(data=popular_book[popular_book['rating']>1], x='book_title', alpha=0.5, ax=ax1[1].twinx())
plt.show()

# %% [markdown]
# 많이 읽힌 책들은 중앙값 8점대를 형성하고 있음을 확인할 수 있습니다.
#
# 다음으로 book cate 별 rating 차이를 알아보겠습니다
#
# 앞서 만든 상위 카테고리를 활용하여 살펴보겠습니다.

# %%
popular_cate_list = data['category_high'].value_counts().sort_values(ascending=False)[:10].index
popular_cate = data[data['category_high'].isin(popular_cate_list)]

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))

plot1 = sns.barplot(data=popular_cate[popular_cate['rating']>1], x='category_high', y='rating', estimator=np.mean, ax=ax[0], )
plot2 = sns.barplot(data=popular_cate[popular_cate['rating']>1], x='category_high', y='rating', estimator=np.median, ax=ax[1])
plot1.set_xticklabels(plot1.get_xticklabels(), rotation=45)
plot2.set_xticklabels(plot2.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# 카테고리 간 점수차이는 크게 없습니다.

# %%
fig, ax = plt.subplots(1,2,figsize=(20,5))

plot1 = sns.barplot(data=popular_cate, x='category_high', y='rating', estimator=np.mean, ax=ax[0], )
plot2 = sns.barplot(data=popular_cate, x='category_high', y='rating', estimator=np.median, ax=ax[1])
plot1.set_xticklabels(plot1.get_xticklabels(), rotation=45)
plot2.set_xticklabels(plot2.get_xticklabels(), rotation=45)
plt.show()

# %% [markdown]
# 본 미션은 여기까지 입니다.
#
# 대회 데이터를 이해하고 이를 바탕으로 간단한 Feature engineering을 수행하는 시간을 가져보았습니다.
#
# 미션을 따라오시면서 궁금했던 점들을 직접 해보시면 데이터를 더 잘 이해할 수 있게 될 것입니다.
#
# 본 미션을 통해 분석 아이디어를 얻어서 대회에서 다양한 시도를 많이 해보시며 실력을 쌓으시길 바라겠습니다.

# %% [markdown]
# # End of Document

# %% [markdown]
# <font color='red'><b>**WARNING**</b></font> : **본 교육 콘텐츠의 지식재산권은 재단법인 네이버커넥트에 귀속됩니다. 본 콘텐츠를 어떠한 경로로든 외부로 유출 및 수정하는 행위를 엄격히 금합니다.** 다만, 비영리적 교육 및 연구활동에 한정되어 사용할 수 있으나 재단의 허락을 받아야 합니다. 이를 위반하는 경우, 관련 법률에 따라 책임을 질 수 있습니다.
