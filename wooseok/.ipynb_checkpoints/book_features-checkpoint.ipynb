# %% [markdown]
# # book_title, publisher, book_author 통일하기

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from dython.nominal import associations

# %%
users = pd.read_csv('users-mod.csv')
ratings = pd.read_csv('ratings-mod.csv')
books = pd.read_csv('books-mod.csv')


JH_dir = '../junhyuk/'
m_books = pd.read_csv(JH_dir+'basic_preprocess_books.csv', index_col = 'Unnamed: 0')

# %%
m_books
# Out:
#               isbn                                         book_title  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0399135782                             The Kitchen God's Wife
# 4       0425176428  What If?: The World's Foremost Military Histor...
# ...            ...                                                ...
# 149565  067161746X  The Bachelor Home Companion: A Practical Guide...
# 149566  0767907566  All Elevations Unknown: An Adventure in the He...
# 149567  0884159221  Why stop?: A guide to Texas historical roadsid...
# 149568  0912333022  The Are You Being Served? Stories: 'Camping In...
# 149569  1569661057  Dallas Street Map Guide and Directory, 2000 Ed...
#
#                  book_author  year_of_publication                 publisher  \
# ...

# %%
gr_ath = m_books.groupby(['book_title','publisher'])['book_author'].apply(','.join)
gr_ath = pd.DataFrame(gr_ath)

# %%
gr_ath
# Out:
#                                                                                        book_author
# book_title                                         publisher
#  A Light in the Storm: The Civil War Diary of A... Hyperion Books for Children         Karen Hesse
#  Ask Lily (Young Women of Faith: Lily Series, B... Zonderkidz                         Nancy N. Rue
#  Dark Justice                                      Putnam Publishing Group            Jack Higgins
#  Earth Prayers From around the World: 365 Praye... HarperSanFrancisco            Elizabeth Roberts
#  Final Fantasy Anthology: Official Strategy Gui... BradyGames                        David Cassady
# ...                                                                                            ...
# Ã?Â?bernachten mit Stil. Die schÃ?Â¶nsten Count... Reich, Luzern                Christopher Fennel
# Ã?Â?rger mit Produkt X. Roman.                     Diogenes Verlag                      Joan Aiken
# ...

# %%
# gr_ath[gr_ath['book_author'].str.contains(',')]
gr_ath['book_author'] = gr_ath['book_author'].str.split(',')
gr_ath
# Out:
#                                                                                          book_author
# book_title                                         publisher
#  A Light in the Storm: The Civil War Diary of A... Hyperion Books for Children         [Karen Hesse]
#  Ask Lily (Young Women of Faith: Lily Series, B... Zonderkidz                         [Nancy N. Rue]
#  Dark Justice                                      Putnam Publishing Group            [Jack Higgins]
#  Earth Prayers From around the World: 365 Praye... HarperSanFrancisco            [Elizabeth Roberts]
#  Final Fantasy Anthology: Official Strategy Gui... BradyGames                        [David Cassady]
# ...                                                                                              ...
# Ã?Â?bernachten mit Stil. Die schÃ?Â¶nsten Count... Reich, Luzern                [Christopher Fennel]
# Ã?Â?rger mit Produkt X. Roman.                     Diogenes Verlag                      [Joan Aiken]
# ...

# %%
gr_ath['book_author'].str.len()
# Out:
# book_title                                                                                                  publisher
#  A Light in the Storm: The Civil War Diary of Amelia Martin, Fenwick Island, Delaware, 1861 (Dear America)  Hyperion Books for Children    1
#  Ask Lily (Young Women of Faith: Lily Series, Book 5)                                                       Zonderkidz                     1
#  Dark Justice                                                                                               Putnam Publishing Group        1
#  Earth Prayers From around the World: 365 Prayers, Poems, and Invocations for Honoring the Earth            HarperSanFrancisco             1
#  Final Fantasy Anthology: Official Strategy Guide (Brady Games)                                             BradyGames                     1
#                                                                                                                                           ..
# ...

# %%
pd.options.display.max_rows = 200
gr_ath[gr_ath['book_author'].str.len() >= 2]
# Out:
#                                                                                                                          book_author
# book_title                                         publisher
# 10,000 dreams interpreted: A dictionary of dreams  Barnes & Nobles Books           [Gustavus Hindman Miller, Gustavus Hindman Mil...
# 1001 Really Cool Web Sites                         Thomson Learning                                         [Edward J.,  Jr Renehan]
# 101 Famous Poems                                   McGraw-Hill/Contemporary Books                         [Roy J. Cook, Roy J. Cook]
# 101 Ways to Your Husbands Heart/Wifes Heart        Thomas Nelson Inc                                  [Nick and Allan,  Rosie Allan]
# 158 POUND MARRIAGE                                 Pocket                                                 [John Irving, John Irving]
# ...

# %%
m_books
# Out:
#               isbn                                         book_title  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0399135782                             The Kitchen God's Wife
# 4       0425176428  What If?: The World's Foremost Military Histor...
# ...            ...                                                ...
# 149565  067161746X  The Bachelor Home Companion: A Practical Guide...
# 149566  0767907566  All Elevations Unknown: An Adventure in the He...
# 149567  0884159221  Why stop?: A guide to Texas historical roadsid...
# 149568  0912333022  The Are You Being Served? Stories: 'Camping In...
# 149569  1569661057  Dallas Street Map Guide and Directory, 2000 Ed...
#
#                  book_author  year_of_publication                 publisher  \
# ...

# %%
gr_ath[gr_ath['book_author'].str.len() >= 3]
# Out:
#                                                                                                                                  book_author
# book_title                                         publisher
# A Son of the Circus                                Ballantine Books                                  [John Irving, John Irving, John Irving]
# About a Boy                                        Penguin Books Ltd                                 [Nick Hornby, Nick Hornby, Nick Hornby]
# Adventures of Stainless Steel Rat                  Berkley Publishing Group                           [Harry Harrison, Harry,  Jr. Harrison]
# All Creatures Great and Small                      Bantam Books                                [James Herriot, James Herriot, James Herriot]
# Almost Forever                                     Mira                                           [Linda Howard, Linda Howard, Linda Howard]
# ...
